# %%
import numpy as np
import random
n = 40428967  #total number of records in the clickstream data 
sample_size = 1000000
skip_values = sorted(random.sample(range(1,n), n-sample_size)) 

types_train = {
    'id': np.dtype(int),
    'click': np.dtype(int),
    'hour': np.dtype(int),
    'C1': np.dtype(int),
    'banner_pos': np.dtype(int),
    'site_id': np.dtype(str),
    'site_domain': np.dtype(str), 
    'site_category': np.dtype(str),
    'app_id': np.dtype(str),
    'app_domain': np.dtype(str),
    'app_category': np.dtype(str),
    'device_id': np.dtype(str),
    'device_ip': np.dtype(str),
    'device_model': np.dtype(str),
    'device_type': np.dtype(int),
    'device_conn_type': np.dtype(int),
    'C14': np.dtype(int),
    'C15': np.dtype(int),
    'C16': np.dtype(int),
    'C17': np.dtype(int),
    'C18': np.dtype(int),
    'C19': np.dtype(int),
    'C20': np.dtype(int),
    'C21':np.dtype(int)
}


types_test = {
    'id': np.dtype(int),
    'hour': np.dtype(int),
    'C1': np.dtype(int),
    'banner_pos': np.dtype(int),
    'site_id': np.dtype(str),
    'site_domain': np.dtype(str), 
    'site_category': np.dtype(str),
    'app_id': np.dtype(str),
    'app_domain': np.dtype(str),
    'app_category': np.dtype(str),
    'device_id': np.dtype(str),
    'device_ip': np.dtype(str),
    'device_model': np.dtype(str),
    'device_type': np.dtype(int),
    'device_conn_type': np.dtype(int),
    'C14': np.dtype(int),
    'C15': np.dtype(int),
    'C16': np.dtype(int),
    'C17': np.dtype(int),
    'C18': np.dtype(int),
    'C19': np.dtype(int),
    'C20': np.dtype(int),
    'C21':np.dtype(int)
}

# %%
import pandas as pd
import gzip

parse_date = lambda val : pd.datetime.strptime(val, '%y%m%d%H')

with gzip.open(r'C:\Users\Sarve\Downloads\kaggle project\click through rate prediction\train.gz') as f:
    train = pd.read_csv(f, parse_dates = ['hour'], date_parser = parse_date, dtype=types_train, skiprows = skip_values)

train.head()
# Out:
#            id  click       hour    C1  banner_pos   site_id site_domain  \
# 0   349511846      0 2014-10-21  1005           0  6ec06dbd    d262cf1e
# 1  1575983631      0 2014-10-21  1005           0  85f751fd    c4e18dd6
# 2  -324854646      0 2014-10-21  1005           0  1fbe01fe    f3845767
# 3  2000318493      0 2014-10-21  1005           1  e151e245    7e091613
# 4 -1377166291      0 2014-10-21  1005           0  1fbe01fe    f3845767
#
#   site_category    app_id app_domain  ... device_type device_conn_type    C14  \
# 0      f66779e6  ecad2386   7801e8d9  ...           1                0  19870
# 1      50e219e0  396df801   2347f47a  ...           1                0  15705
# 2      28905ebd  ecad2386   7801e8d9  ...           1                0  15702
# 3      f028772b  ecad2386   7801e8d9  ...           1                0  20359
# 4      28905ebd  ecad2386   7801e8d9  ...           1                0  15704
#
#    C15  C16   C17  C18  C19     C20  C21
# 0  320   50  2271    0  687  100075   48
# 1  320   50  1722    0   35  100084   79
# 2  320   50  1722    0   35      -1   79
# 3  216   36  2333    0   39      -1  157
# 4  320   50  1722    0   35      -1   79
#
# [5 rows x 24 columns]

# %%
train.shape
# Out:
# (1000000, 24)

# %%
train.dtypes
# Out:
# id                           int32
# click                        int32
# hour                datetime64[ns]
# C1                           int32
# banner_pos                   int32
# site_id                     object
# site_domain                 object
# site_category               object
# app_id                      object
# app_domain                  object
# app_category                object
# device_id                   object
# device_ip                   object
# device_model                object
# device_type                  int32
# device_conn_type             int32
# C14                          int32
# C15                          int32
# C16                          int32
# C17                          int32
# C18                          int32
# C19                          int32
# C20                          int32
# C21                          int32
# dtype: object

# %%
train['click'].value_counts()
# Out:
# 0    830182
# 1    169818
# Name: click, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='click',data=train, palette='hls')
plt.show();

# %%
train['click'].value_counts()/len(train)
# Out:
# 0    0.830182
# 1    0.169818
# Name: click, dtype: float64

# %%
train.hour.describe()
# Out:
# count                 1000000
# unique                    240
# top       2014-10-22 09:00:00
# freq                    10996
# first     2014-10-21 00:00:00
# last      2014-10-30 23:00:00
# Name: hour, dtype: object

# %%
train.groupby('hour').agg({'click':'sum'}).plot(figsize=(12,6))
plt.ylabel('Number of clicks')
plt.title('Number of clicks by hour');

# %%
train['hour_of_day'] = train.hour.apply(lambda x: x.hour)
train.groupby('hour_of_day').agg({'click':'sum'}).plot(figsize=(12,6))
plt.ylabel('Number of clicks')
plt.title('click trends by hour of day');

# %%
train.head(3)
# Out:
#            id  click       hour    C1  banner_pos   site_id site_domain  \
# 0   349511846      0 2014-10-21  1005           0  6ec06dbd    d262cf1e
# 1  1575983631      0 2014-10-21  1005           0  85f751fd    c4e18dd6
# 2  -324854646      0 2014-10-21  1005           0  1fbe01fe    f3845767
#
#   site_category    app_id app_domain  ... device_conn_type    C14  C15 C16  \
# 0      f66779e6  ecad2386   7801e8d9  ...                0  19870  320  50
# 1      50e219e0  396df801   2347f47a  ...                0  15705  320  50
# 2      28905ebd  ecad2386   7801e8d9  ...                0  15702  320  50
#
#     C17  C18  C19     C20  C21  hour_of_day
# 0  2271    0  687  100075   48            0
# 1  1722    0   35  100084   79            0
# 2  1722    0   35      -1   79            0
#
# [3 rows x 25 columns]

# %%
train.groupby(['hour_of_day', 'click']).size().unstack().plot(kind='bar', title="Hour of Day", figsize=(12,6))
plt.ylabel('count')
plt.title('Hourly impressions vs. clicks');

# %%
train.head(3)
# Out:
#            id  click       hour    C1  banner_pos   site_id site_domain  \
# 0   349511846      0 2014-10-21  1005           0  6ec06dbd    d262cf1e
# 1  1575983631      0 2014-10-21  1005           0  85f751fd    c4e18dd6
# 2  -324854646      0 2014-10-21  1005           0  1fbe01fe    f3845767
#
#   site_category    app_id app_domain  ... device_conn_type    C14  C15 C16  \
# 0      f66779e6  ecad2386   7801e8d9  ...                0  19870  320  50
# 1      50e219e0  396df801   2347f47a  ...                0  15705  320  50
# 2      28905ebd  ecad2386   7801e8d9  ...                0  15702  320  50
#
#     C17  C18  C19     C20  C21  hour_of_day
# 0  2271    0  687  100075   48            0
# 1  1722    0   35  100084   79            0
# 2  1722    0   35      -1   79            0
#
# [3 rows x 25 columns]

# %%
import seaborn as sns

df_click = train[train['click'] == 1]
df_hour = train[['hour_of_day','click']].groupby(['hour_of_day']).count().reset_index()
df_hour = df_hour.rename(columns={'click': 'impressions'})
df_hour['clicks'] = df_click[['hour_of_day','click']].groupby(['hour_of_day']).count().reset_index()['click']
df_hour['CTR'] = df_hour['clicks']/df_hour['impressions']*100

plt.figure(figsize=(12,6))
sns.barplot(y='CTR', x='hour_of_day', data=df_hour)
plt.title('Hourly CTR');

# %%
train['day_of_week'] = train['hour'].apply(lambda val: val.weekday_name)
cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
train.groupby('day_of_week').agg({'click':'sum'}).reindex(cats).plot(figsize=(12,6))
ticks = list(range(0, 7, 1)) # points on the x axis where you want the label to appear
labels = "Mon Tues Weds Thurs Fri Sat Sun".split()
plt.xticks(ticks, labels)
plt.title('click trends by day of week');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
#   """Entry point for launching an IPython kernel.

# %%
train.groupby(['day_of_week','click']).size().unstack().reindex(cats).plot(kind='bar', title="Day of the Week", figsize=(12,6))
ticks = list(range(0, 7, 1)) # points on the x axis where you want the label to appear
labels = "Mon Tues Weds Thurs Fri Sat Sun".split()
plt.xticks(ticks, labels)
plt.title('Impressions vs. clicks by day of week');

# %%
train.head(3)
# Out:
#            id  click       hour    C1  banner_pos   site_id site_domain  \
# 0   349511846      0 2014-10-21  1005           0  6ec06dbd    d262cf1e
# 1  1575983631      0 2014-10-21  1005           0  85f751fd    c4e18dd6
# 2  -324854646      0 2014-10-21  1005           0  1fbe01fe    f3845767
#
#   site_category    app_id app_domain  ...    C14  C15 C16   C17  C18  C19  \
# 0      f66779e6  ecad2386   7801e8d9  ...  19870  320  50  2271    0  687
# 1      50e219e0  396df801   2347f47a  ...  15705  320  50  1722    0   35
# 2      28905ebd  ecad2386   7801e8d9  ...  15702  320  50  1722    0   35
#
#       C20  C21  hour_of_day  day_of_week
# 0  100075   48            0      Tuesday
# 1  100084   79            0      Tuesday
# 2      -1   79            0      Tuesday
#
# [3 rows x 26 columns]

# %%
df_click = train[train['click'] == 1]
df_dayofweek = train[['day_of_week','click']].groupby(['day_of_week']).count().reset_index()
df_dayofweek = df_dayofweek.rename(columns={'click': 'impressions'})
df_dayofweek['clicks'] = df_click[['day_of_week','click']].groupby(['day_of_week']).count().reset_index()['click']
df_dayofweek['CTR'] = df_dayofweek['clicks']/df_dayofweek['impressions']*100

plt.figure(figsize=(12,6))
sns.barplot(y='CTR', x='day_of_week', data=df_dayofweek, order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Day of week CTR');

# %%
train.head(3)
# Out:
#            id  click       hour    C1  banner_pos   site_id site_domain  \
# 0   349511846      0 2014-10-21  1005           0  6ec06dbd    d262cf1e
# 1  1575983631      0 2014-10-21  1005           0  85f751fd    c4e18dd6
# 2  -324854646      0 2014-10-21  1005           0  1fbe01fe    f3845767
#
#   site_category    app_id app_domain  ...    C14  C15 C16   C17  C18  C19  \
# 0      f66779e6  ecad2386   7801e8d9  ...  19870  320  50  2271    0  687
# 1      50e219e0  396df801   2347f47a  ...  15705  320  50  1722    0   35
# 2      28905ebd  ecad2386   7801e8d9  ...  15702  320  50  1722    0   35
#
#       C20  C21  hour_of_day  day_of_week
# 0  100075   48            0      Tuesday
# 1  100084   79            0      Tuesday
# 2      -1   79            0      Tuesday
#
# [3 rows x 26 columns]

# %%
print(train.C1.value_counts()/len(train))
# Out:
# 1005    0.918507
# 1002    0.055074
# 1010    0.022316
# 1012    0.002858
# 1007    0.000869
# 1001    0.000217
# 1008    0.000159
# Name: C1, dtype: float64

# %%
C1_values = train.C1.unique()
C1_values.sort()
ctr_avg_list=[]
for i in C1_values:
    ctr_avg=train.loc[np.where((train.C1 == i))].click.mean()
    ctr_avg_list.append(ctr_avg)
    print("for C1 value: {},  click through rate: {}".format(i,ctr_avg))
# Out:
# for C1 value: 1001,  click through rate: 0.05069124423963134
# for C1 value: 1002,  click through rate: 0.21126121218723898
# for C1 value: 1005,  click through rate: 0.16927470340454673
# for C1 value: 1007,  click through rate: 0.03567318757192175
# for C1 value: 1008,  click through rate: 0.13836477987421383
# for C1 value: 1010,  click through rate: 0.0960745653342893
# for C1 value: 1012,  click through rate: 0.17319804058782365

# %%
train.groupby(['C1', 'click']).size().unstack().plot(kind='bar', figsize=(12,6), title='C1 histogram');

# %%
df_c1 = train[['C1','click']].groupby(['C1']).count().reset_index()
df_c1 = df_c1.rename(columns={'click': 'impressions'})
df_c1['clicks'] = df_click[['C1','click']].groupby(['C1']).count().reset_index()['click']
df_c1['CTR'] = df_c1['clicks']/df_c1['impressions']*100

plt.figure(figsize=(12,6))
sns.barplot(y='CTR', x='C1', data=df_c1)
plt.title('CTR by C1');

# %%
train['click'].mean()
# Out:
# 0.169818

# %%
df_c1.CTR.describe()
# Out:
# count     7.000000
# mean     12.493396
# std       6.613198
# min       3.567319
# 25%       7.338290
# 50%      13.836478
# 75%      17.123637
# max      21.126121
# Name: CTR, dtype: float64

# %%
print(train.banner_pos.value_counts()/len(train))
# Out:
# 0    0.719723
# 1    0.278524
# 7    0.001065
# 2    0.000314
# 4    0.000166
# 5    0.000158
# 3    0.000050
# Name: banner_pos, dtype: float64

# %%
banner_pos = train.banner_pos.unique()
banner_pos.sort()
ctr_avg_list=[]
for i in banner_pos:
    ctr_avg=train.loc[np.where((train.banner_pos == i))].click.mean()
    ctr_avg_list.append(ctr_avg)
    print("for banner position: {},  click through rate: {}".format(i,ctr_avg))
# Out:
# for banner position: 0,  click through rate: 0.16418677741297694
# for banner position: 1,  click through rate: 0.18392310896008962
# for banner position: 2,  click through rate: 0.11146496815286625
# for banner position: 3,  click through rate: 0.22
# for banner position: 4,  click through rate: 0.14457831325301204
# for banner position: 5,  click through rate: 0.13924050632911392
# for banner position: 7,  click through rate: 0.30985915492957744

# %%
train.groupby(['banner_pos', 'click']).size().unstack().plot(kind='bar', figsize=(12,6), title='banner position histogram');

# %%
df_banner = train[['banner_pos','click']].groupby(['banner_pos']).count().reset_index()
df_banner = df_banner.rename(columns={'click': 'impressions'})
df_banner['clicks'] = df_click[['banner_pos','click']].groupby(['banner_pos']).count().reset_index()['click']
df_banner['CTR'] = df_banner['clicks']/df_banner['impressions']*100
sort_banners = df_banner.sort_values(by='CTR',ascending=False)['banner_pos'].tolist()
plt.figure(figsize=(12,6))
sns.barplot(y='CTR', x='banner_pos', data=df_banner, order=sort_banners)
plt.title('CTR by banner position');

# %%
df_banner.CTR.describe()
# Out:
# count     7.000000
# mean     18.189326
# std       6.622794
# min      11.146497
# 25%      14.190941
# 50%      16.418678
# 75%      20.196155
# max      30.985915
# Name: CTR, dtype: float64

# %%
print("There are {} sites in the data set".format(train.site_id.nunique()))
# Out:
# There are 2698 sites in the data set

# %%
print('The top 10 site ids that have the most impressions')
print((train.site_id.value_counts()/len(train))[0:10])
# Out:
# The top 10 site ids that have the most impressions
# 85f751fd    0.360840
# 1fbe01fe    0.160386
# e151e245    0.065434
# d9750ee7    0.023909
# 5b08c53b    0.022650
# 856e6d3f    0.019071
# 5b4d2eda    0.018981
# a7853007    0.011472
# b7e9786d    0.009237
# 5ee41ff2    0.008715
# Name: site_id, dtype: float64

# %%
top10_ids = (train.site_id.value_counts()/len(train))[0:10].index
click_avg_list=[]

for i in top10_ids:
    click_avg=train.loc[np.where((train.site_id == i))].click.mean()
    click_avg_list.append(click_avg)
    print("for site id value: {},  click through rate: {}".format(i,click_avg))
# Out:
# for site id value: 85f751fd,  click through rate: 0.11842090677308502
# for site id value: 1fbe01fe,  click through rate: 0.20574114947688701
# for site id value: e151e245,  click through rate: 0.2944035211052358
# for site id value: d9750ee7,  click through rate: 0.28411895102262746
# for site id value: 5b08c53b,  click through rate: 0.4642384105960265
# for site id value: 856e6d3f,  click through rate: 0.040480310418960726
# for site id value: 5b4d2eda,  click through rate: 0.12633686317896844
# for site id value: a7853007,  click through rate: 0.10460251046025104
# for site id value: b7e9786d,  click through rate: 0.07870520731839342
# for site id value: 5ee41ff2,  click through rate: 0.3272518646012622

# %%
top10_sites = train[(train.site_id.isin((train.site_id.value_counts()/len(train))[0:10].index))]
top10_sites_click = top10_sites[top10_sites['click'] == 1]
top10_sites.groupby(['site_id', 'click']).size().unstack().plot(kind='bar', figsize=(12,6), title='Top 10 site ids histogram');

# %%
df_site = top10_sites[['site_id','click']].groupby(['site_id']).count().reset_index()
df_site = df_site.rename(columns={'click': 'impressions'})
df_site['clicks'] = top10_sites_click[['site_id','click']].groupby(['site_id']).count().reset_index()['click']
df_site['CTR'] = df_site['clicks']/df_site['impressions']*100
sort_site = df_site.sort_values(by='CTR',ascending=False)['site_id'].tolist()
plt.figure(figsize=(12,6))
sns.barplot(y='CTR', x='site_id', data=df_site, order=sort_site)
plt.title('CTR by top 10 site id');

# %%
print("There are {} site domains in the data set".format(train.site_domain.nunique()))
# Out:
# There are 2870 site domains in the data set

# %%
print('The top 10 site domains that have the most impressions')
print((train.site_domain.value_counts()/len(train))[0:10])
# Out:
# The top 10 site domains that have the most impressions
# c4e18dd6    0.374360
# f3845767    0.160386
# 7e091613    0.082469
# 7687a86e    0.031951
# 98572c79    0.024733
# 16a36ef3    0.021049
# 58a89a43    0.019071
# 9d54950b    0.009344
# b12b9f85    0.009341
# 17d996e6    0.008842
# Name: site_domain, dtype: float64

# %%
top10_domains = (train.site_domain.value_counts()/len(train))[0:10].index
click_avg_list=[]

for i in top10_domains:
    click_avg=train.loc[np.where((train.site_domain == i))].click.mean()
    click_avg_list.append(click_avg)
    print("for site domain value: {},  click through rate: {}".format(i,click_avg))
# Out:
# for site domain value: c4e18dd6,  click through rate: 0.12243028101292873
# for site domain value: f3845767,  click through rate: 0.20574114947688701
# for site domain value: 7e091613,  click through rate: 0.25739368732493423
# for site domain value: 7687a86e,  click through rate: 0.4590153672811493
# for site domain value: 98572c79,  click through rate: 0.27748352403671206
# for site domain value: 16a36ef3,  click through rate: 0.13820133973110363
# for site domain value: 58a89a43,  click through rate: 0.040480310418960726
# for site domain value: 9d54950b,  click through rate: 0.11825770547945205
# for site domain value: b12b9f85,  click through rate: 0.07986296970345787
# for site domain value: 17d996e6,  click through rate: 0.32515268038905226

# %%
top10_domain = train[(train.site_domain.isin((train.site_domain.value_counts()/len(train))[0:10].index))]
top10_domain_click = top10_domain[top10_domain['click'] == 1]
top10_domain.groupby(['site_domain', 'click']).size().unstack().plot(kind='bar', figsize=(12,6), title='Top 10 site domains histogram');

# %%
df_domain = top10_domain[['site_domain','click']].groupby(['site_domain']).count().reset_index()
df_domain = df_domain.rename(columns={'click': 'impressions'})
df_domain['clicks'] = top10_domain_click[['site_domain','click']].groupby(['site_domain']).count().reset_index()['click']
df_domain['CTR'] = df_domain['clicks']/df_domain['impressions']*100
sort_domain = df_domain.sort_values(by='CTR',ascending=False)['site_domain'].tolist()
plt.figure(figsize=(12,6))
sns.barplot(y='CTR', x='site_domain', data=df_domain, order=sort_domain)
plt.title('CTR by top 10 site domain');

# %%
print("There are {} site categories in the data set".format(train.site_category.nunique()))
# Out:
# There are 22 site categories in the data set

# %%
print('The top 10 site categories that have the most impressions')
print((train.site_category.value_counts()/len(train))[0:10])
# Out:
# The top 10 site categories that have the most impressions
# 50e219e0    0.408981
# f028772b    0.313495
# 28905ebd    0.182252
# 3e814130    0.075302
# f66779e6    0.006331
# 75fa27f6    0.003986
# 335d28a8    0.003361
# 76b2941d    0.002528
# c0dd3be3    0.001041
# 72722551    0.000702
# Name: site_category, dtype: float64

# %%
top10_categories = (train.site_category.value_counts()/len(train))[0:10].index
click_avg_list=[]

for i in top10_categories:
    click_avg=train.loc[np.where((train.site_category == i))].click.mean()
    click_avg_list.append(click_avg)
    print("for site category value: {},  click through rate: {}".format(i,click_avg))
# Out:
# for site category value: 50e219e0,  click through rate: 0.12823089581178587
# for site category value: f028772b,  click through rate: 0.17941593964816024
# for site category value: 28905ebd,  click through rate: 0.20865065952637007
# for site category value: 3e814130,  click through rate: 0.28391012190911263
# for site category value: f66779e6,  click through rate: 0.04454272626757226
# for site category value: 75fa27f6,  click through rate: 0.11164074259909684
# for site category value: 335d28a8,  click through rate: 0.09015174055340672
# for site category value: 76b2941d,  click through rate: 0.035205696202531646
# for site category value: c0dd3be3,  click through rate: 0.11335254562920269
# for site category value: 72722551,  click through rate: 0.05413105413105413

# %%
top10_category = train[(train.site_category.isin((train.site_category.value_counts()/len(train))[0:10].index))]
top10_category_click = top10_category[top10_category['click'] == 1]
top10_category.groupby(['site_category', 'click']).size().unstack().plot(kind='bar', figsize=(12,6), title='Top 10 site categories histogram');

# %%
df_category = top10_category[['site_category','click']].groupby(['site_category']).count().reset_index()
df_category = df_category.rename(columns={'click': 'impressions'})
df_category['clicks'] = top10_category_click[['site_category','click']].groupby(['site_category']).count().reset_index()['click']
df_category['CTR'] = df_category['clicks']/df_category['impressions']*100
sort_category = df_category.sort_values(by='CTR',ascending=False)['site_category'].tolist()
plt.figure(figsize=(12,6))
sns.barplot(y='CTR', x='site_category', data=df_category, order=sort_category)
plt.title('CTR by top 10 site category');

# %%
print("There are {} devices in the data set".format(train.device_id.nunique()))
# Out:
# There are 149788 devices in the data set

# %%
print('The top 10 devices that have the most impressions')
print((train.device_id.value_counts()/len(train))[0:10])
# Out:
# The top 10 devices that have the most impressions
# a99f214a    0.825504
# 0f7c61dc    0.000549
# c357dbff    0.000490
# 936e92fb    0.000335
# afeffc18    0.000240
# 987552d1    0.000118
# b09da1c4    0.000106
# d857ffbb    0.000097
# 28dc8687    0.000093
# 3cdb4052    0.000080
# Name: device_id, dtype: float64

# %%
top10_devices = (train.device_id.value_counts()/len(train))[0:10].index
click_avg_list=[]

for i in top10_devices:
    click_avg=train.loc[np.where((train.device_id == i))].click.mean()
    click_avg_list.append(click_avg)
    print("for device id value: {},  click through rate: {}".format(i,click_avg))
# Out:
# for device id value: a99f214a,  click through rate: 0.17419176648447493
# for device id value: 0f7c61dc,  click through rate: 0.7978142076502732
# for device id value: c357dbff,  click through rate: 0.6265306122448979
# for device id value: 936e92fb,  click through rate: 0.04776119402985075
# for device id value: afeffc18,  click through rate: 0.19583333333333333
# for device id value: 987552d1,  click through rate: 0.0
# for device id value: b09da1c4,  click through rate: 0.09433962264150944
# for device id value: d857ffbb,  click through rate: 0.15463917525773196
# for device id value: 28dc8687,  click through rate: 0.0
# for device id value: 3cdb4052,  click through rate: 0.825

# %%
top10_device = train[(train.device_id.isin((train.device_id.value_counts()/len(train))[0:10].index))]
top10_device_click = top10_device[top10_device['click'] == 1]
top10_device.groupby(['device_id', 'click']).size().unstack().plot(kind='bar', figsize=(12,6), title='Top 10 device ids histogram');

# %%
print("There are {} device ips in the data set".format(train.device_ip.nunique()))
print("There are {} device types in the data set".format(train.device_type.nunique()))
print("There are {} device models in the data set".format(train.device_model.nunique()))
print("There are {} device cnn types in the data set".format(train.device_conn_type.nunique()))
# Out:
# There are 555322 device ips in the data set
# There are 5 device types in the data set
# There are 5133 device models in the data set
# There are 4 device cnn types in the data set

# %%
print('The impressions by device types')
print((train.device_type.value_counts()/len(train)))
# Out:
# The impressions by device types
# 1    0.922609
# 0    0.055074
# 4    0.019128
# 5    0.003188
# 2    0.000001
# Name: device_type, dtype: float64

# %%
train[['device_type','click']].groupby(['device_type','click']).size().unstack().plot(kind='bar', title='device types');

# %%
df_click[df_click['device_type']==1].groupby(['hour_of_day', 'click']).size().unstack().plot(kind='bar', title="Clicks from device type 1 by hour of day", figsize=(12,6));

# %%
device_type_click = df_click.groupby('device_type').agg({'click':'sum'}).reset_index()
device_type_impression = train.groupby('device_type').agg({'click':'count'}).reset_index().rename(columns={'click': 'impressions'})
merged_device_type = pd.merge(left = device_type_click , right = device_type_impression, how = 'inner', on = 'device_type')

# %%
merged_device_type['CTR'] = merged_device_type['click'] / merged_device_type['impressions']*100

# %%
merged_device_type
# Out:
#    device_type   click  impressions        CTR
# 0            0   11635        55074  21.126121
# 1            1  156039       922609  16.912798
# 2            4    1846        19128   9.650774
# 3            5     298         3188   9.347553

# %%
print("There are {} apps in the data set".format(train.app_id.nunique()))
print("There are {} app domains in the data set".format(train.app_domain.nunique()))
print("There are {} app categories in the data set".format(train.app_category.nunique()))
# Out:
# There are 3106 apps in the data set
# There are 207 app domains in the data set
# There are 26 app categories in the data set

# %%
print('The impressions by app categories')
print((train.app_category.value_counts()/len(train)))
# Out:
# The impressions by app categories
# 07d7df22    0.647483
# 0f2161f8    0.236101
# cef3e649    0.042600
# 8ded1f7a    0.036493
# f95efa07    0.028268
# d1327cf5    0.003109
# dc97ec06    0.001375
# 09481d60    0.001360
# 75d80bbe    0.001005
# fc6fa53d    0.000580
# 4ce2e9fc    0.000518
# 879c24eb    0.000339
# a3c42688    0.000279
# 4681bb9d    0.000154
# 0f9a328c    0.000142
# 2281a340    0.000052
# a86a3e89    0.000046
# 8df2e842    0.000045
# 0bfbc358    0.000013
# a7fd01ec    0.000010
# 7113d72a    0.000007
# 2fc4f2aa    0.000006
# 79f0b860    0.000006
# 18b1e0be    0.000004
# 5326cf99    0.000003
# 0d82db25    0.000002
# Name: app_category, dtype: float64

# %%
train['app_category'].value_counts().plot(kind='bar', title='App Category v/s Clicks')

# %%
train_app_category = train.groupby(['app_category', 'click']).size().unstack()
train_app_category.div(train_app_category.sum(axis=1), axis=0).plot(kind='bar', stacked=True, title="Intra-category CTR");

# %%
print("There are {} C14 in the data set".format(train.C14.nunique()))
print("There are {} C15 in the data set".format(train.C15.nunique()))
print("There are {} C16 in the data set".format(train.C16.nunique()))
print("There are {} C17 in the data set".format(train.C17.nunique()))
print("There are {} C18 in the data set".format(train.C18.nunique()))
print("There are {} C19 in the data set".format(train.C19.nunique()))
print("There are {} C20 in the data set".format(train.C20.nunique()))
# Out:
# There are 2248 C14 in the data set
# There are 8 C15 in the data set
# There are 9 C16 in the data set
# There are 421 C17 in the data set
# There are 4 C18 in the data set
# There are 65 C19 in the data set
# There are 163 C20 in the data set

# %%
train.groupby(['C15', 'click']).size().unstack().plot(kind='bar', stacked=True, title='C15 distribution');

# %%
train.groupby(['C16', 'click']).size().unstack().plot(kind='bar', stacked=True, title='C16 distribution');

# %%
train.groupby(['C18', 'click']).size().unstack().plot(kind='bar', stacked=True, title='C18 distribution');

# %%
train.head(3)
# Out:
#            id  click       hour    C1  banner_pos   site_id site_domain  \
# 0   349511846      0 2014-10-21  1005           0  6ec06dbd    d262cf1e
# 1  1575983631      0 2014-10-21  1005           0  85f751fd    c4e18dd6
# 2  -324854646      0 2014-10-21  1005           0  1fbe01fe    f3845767
#
#   site_category    app_id app_domain  ...    C14  C15 C16   C17  C18  C19  \
# 0      f66779e6  ecad2386   7801e8d9  ...  19870  320  50  2271    0  687
# 1      50e219e0  396df801   2347f47a  ...  15705  320  50  1722    0   35
# 2      28905ebd  ecad2386   7801e8d9  ...  15702  320  50  1722    0   35
#
#       C20  C21  hour_of_day  day_of_week
# 0  100075   48            0      Tuesday
# 1  100084   79            0      Tuesday
# 2      -1   79            0      Tuesday
#
# [3 rows x 26 columns]

# %%
def convert_obj_to_int(self):
    
    object_list_columns = self.columns
    object_list_dtypes = self.dtypes
    new_col_suffix = '_int'
    for index in range(0,len(object_list_columns)):
        if object_list_dtypes[index] == object :
            self[object_list_columns[index]+new_col_suffix] = self[object_list_columns[index]].map( lambda  x: hash(x))
            self.drop([object_list_columns[index]],inplace=True,axis=1)
    return self
train = convert_obj_to_int(train)

# %%
train.head(3)
# Out:
#            id  click       hour    C1  banner_pos  device_type  \
# 0   349511846      0 2014-10-21  1005           0            1
# 1  1575983631      0 2014-10-21  1005           0            1
# 2  -324854646      0 2014-10-21  1005           0            1
#
#    device_conn_type    C14  C15  C16  ...          site_id_int  \
# 0                 0  19870  320   50  ... -7283303207744690457
# 1                 0  15705  320   50  ...  5589098402358987625
# 2                 0  15702  320   50  ... -8577476548288489501
#
#        site_domain_int    site_category_int           app_id_int  \
# 0  6530666393198994658 -4267716789387642504  -559693364580370444
# 1  -690112451272800869 -1990665966118786978 -5789212661594446106
# 2 -3598130152049739836  1135547742813040869  -559693364580370444
#
#         app_domain_int     app_category_int       device_id_int  \
# 0  -723364560180958657  4964425751127781474 -761757942586999939
# 1 -8461369305171476794 -7122504725265968897 -761757942586999939
# 2  -723364560180958657  4964425751127781474 -761757942586999939
#
#          device_ip_int     device_model_int      day_of_week_int
# 0  1670145003241929896  5572045926712507447 -6903946209352664518
# 1 -6818624553018051305  4447375562041835136 -6903946209352664518
# 2  4228826490520764242 -8226997861710763938 -6903946209352664518
#
# [3 rows x 26 columns]

# %%
train.drop('hour', axis=1, inplace=True)

# %%
train.drop('id', axis=1, inplace=True)

# %%
import lightgbm as lgb
X_train = train.loc[:, train.columns != 'click']
y_target = train.click.values
#create lightgbm dataset
msk = np.random.rand(len(X_train)) < 0.8
lgb_train = lgb.Dataset(X_train[msk], y_target[msk])
lgb_eval = lgb.Dataset(X_train[~msk], y_target[~msk], reference=lgb_train)

# %%
# specify your configurations as a dict
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': { 'binary_logloss'},
    'num_leaves': 31, # defauly leaves(31) amount for each tree
    'learning_rate': 0.08,
    'feature_fraction': 0.7, # will select 70% features before training each tree
    'bagging_fraction': 0.3, #feature_fraction, but this will random select part of data
    'bagging_freq': 5, #  perform bagging at every 5 iteration
    'verbose': 0
}

print('Start training...')
# train
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=4000,
                valid_sets=lgb_eval,
                early_stopping_rounds=500)
# Out:
# Start training...
# [1]	valid_0's binary_logloss: 0.449388
# Training until validation scores don't improve for 500 rounds
# [2]	valid_0's binary_logloss: 0.444884
# [3]	valid_0's binary_logloss: 0.441182
# [4]	valid_0's binary_logloss: 0.437845
# [5]	valid_0's binary_logloss: 0.435193
# [6]	valid_0's binary_logloss: 0.43286
# [7]	valid_0's binary_logloss: 0.430565
# [8]	valid_0's binary_logloss: 0.428834
# [9]	valid_0's binary_logloss: 0.427149
# [10]	valid_0's binary_logloss: 0.425609
# [11]	valid_0's binary_logloss: 0.424233
# [12]	valid_0's binary_logloss: 0.423034
# [13]	valid_0's binary_logloss: 0.421945
# [14]	valid_0's binary_logloss: 0.420852
# [15]	valid_0's binary_logloss: 0.419923
# [16]	valid_0's binary_logloss: 0.419054
# [17]	valid_0's binary_logloss: 0.418199
# [18]	valid_0's binary_logloss: 0.417516
# [19]	valid_0's binary_logloss: 0.4169
# [20]	valid_0's binary_logloss: 0.416371
# [21]	valid_0's binary_logloss: 0.415898
# [22]	valid_0's binary_logloss: 0.415398
# [23]	valid_0's binary_logloss: 0.414963
# [24]	valid_0's binary_logloss: 0.414565
# [25]	valid_0's binary_logloss: 0.414237
# [26]	valid_0's binary_logloss: 0.413908
# [27]	valid_0's binary_logloss: 0.413588
# [28]	valid_0's binary_logloss: 0.413288
# [29]	valid_0's binary_logloss: 0.412959
# [30]	valid_0's binary_logloss: 0.412734
# [31]	valid_0's binary_logloss: 0.412486
# [32]	valid_0's binary_logloss: 0.412097
# [33]	valid_0's binary_logloss: 0.411832
# [34]	valid_0's binary_logloss: 0.411685
# [35]	valid_0's binary_logloss: 0.411412
# [36]	valid_0's binary_logloss: 0.411111
# [37]	valid_0's binary_logloss: 0.410913
# [38]	valid_0's binary_logloss: 0.41067
# [39]	valid_0's binary_logloss: 0.410456
# [40]	valid_0's binary_logloss: 0.410283
# [41]	valid_0's binary_logloss: 0.410167
# [42]	valid_0's binary_logloss: 0.410045
# [43]	valid_0's binary_logloss: 0.409822
# [44]	valid_0's binary_logloss: 0.409723
# [45]	valid_0's binary_logloss: 0.40962
# [46]	valid_0's binary_logloss: 0.409487
# [47]	valid_0's binary_logloss: 0.409401
# [48]	valid_0's binary_logloss: 0.40929
# [49]	valid_0's binary_logloss: 0.40915
# [50]	valid_0's binary_logloss: 0.408958
# [51]	valid_0's binary_logloss: 0.408864
# [52]	valid_0's binary_logloss: 0.408699
# [53]	valid_0's binary_logloss: 0.408572
# [54]	valid_0's binary_logloss: 0.408458
# [55]	valid_0's binary_logloss: 0.408385
# [56]	valid_0's binary_logloss: 0.408289
# [57]	valid_0's binary_logloss: 0.408183
# [58]	valid_0's binary_logloss: 0.408112
# [59]	valid_0's binary_logloss: 0.40804
# [60]	valid_0's binary_logloss: 0.407883
# [61]	valid_0's binary_logloss: 0.40775
# [62]	valid_0's binary_logloss: 0.407607
# [63]	valid_0's binary_logloss: 0.407522
# [64]	valid_0's binary_logloss: 0.407482
# [65]	valid_0's binary_logloss: 0.407345
# [66]	valid_0's binary_logloss: 0.407254
# [67]	valid_0's binary_logloss: 0.407129
# [68]	valid_0's binary_logloss: 0.407067
# [69]	valid_0's binary_logloss: 0.406969
# [70]	valid_0's binary_logloss: 0.406872
# [71]	valid_0's binary_logloss: 0.406773
# [72]	valid_0's binary_logloss: 0.406694
# [73]	valid_0's binary_logloss: 0.406601
# [74]	valid_0's binary_logloss: 0.406548
# [75]	valid_0's binary_logloss: 0.406494
# [76]	valid_0's binary_logloss: 0.406422
# [77]	valid_0's binary_logloss: 0.406343
# [78]	valid_0's binary_logloss: 0.406294
# [79]	valid_0's binary_logloss: 0.406234
# [80]	valid_0's binary_logloss: 0.406218
# [81]	valid_0's binary_logloss: 0.406175
# [82]	valid_0's binary_logloss: 0.406099
# [83]	valid_0's binary_logloss: 0.406071
# [84]	valid_0's binary_logloss: 0.406028
# [85]	valid_0's binary_logloss: 0.405962
# [86]	valid_0's binary_logloss: 0.405921
# [87]	valid_0's binary_logloss: 0.405847
# [88]	valid_0's binary_logloss: 0.405824
# [89]	valid_0's binary_logloss: 0.405761
# [90]	valid_0's binary_logloss: 0.405743
# [91]	valid_0's binary_logloss: 0.405678
# [92]	valid_0's binary_logloss: 0.405594
# [93]	valid_0's binary_logloss: 0.405553
# [94]	valid_0's binary_logloss: 0.405498
# [95]	valid_0's binary_logloss: 0.405438
# [96]	valid_0's binary_logloss: 0.405398
# [97]	valid_0's binary_logloss: 0.405337
# [98]	valid_0's binary_logloss: 0.405301
# [99]	valid_0's binary_logloss: 0.405274
# [100]	valid_0's binary_logloss: 0.405246
# [101]	valid_0's binary_logloss: 0.405183
# [102]	valid_0's binary_logloss: 0.405106
# [103]	valid_0's binary_logloss: 0.405078
# [104]	valid_0's binary_logloss: 0.405036
# [105]	valid_0's binary_logloss: 0.405002
# [106]	valid_0's binary_logloss: 0.405003
# [107]	valid_0's binary_logloss: 0.405007
# [108]	valid_0's binary_logloss: 0.404988
# [109]	valid_0's binary_logloss: 0.404993
# [110]	valid_0's binary_logloss: 0.40489
# [111]	valid_0's binary_logloss: 0.404834
# [112]	valid_0's binary_logloss: 0.40479
# [113]	valid_0's binary_logloss: 0.404765
# [114]	valid_0's binary_logloss: 0.404745
# [115]	valid_0's binary_logloss: 0.404726
# [116]	valid_0's binary_logloss: 0.404701
# [117]	valid_0's binary_logloss: 0.40466
# [118]	valid_0's binary_logloss: 0.404624
# [119]	valid_0's binary_logloss: 0.404595
# [120]	valid_0's binary_logloss: 0.404572
# [121]	valid_0's binary_logloss: 0.404531
# [122]	valid_0's binary_logloss: 0.404498
# [123]	valid_0's binary_logloss: 0.404463
# [124]	valid_0's binary_logloss: 0.404443
# [125]	valid_0's binary_logloss: 0.404401
# [126]	valid_0's binary_logloss: 0.404359
# [127]	valid_0's binary_logloss: 0.404322
# [128]	valid_0's binary_logloss: 0.404291
# [129]	valid_0's binary_logloss: 0.404265
# [130]	valid_0's binary_logloss: 0.404235
# [131]	valid_0's binary_logloss: 0.404164
# [132]	valid_0's binary_logloss: 0.404147
# [133]	valid_0's binary_logloss: 0.404094
# [134]	valid_0's binary_logloss: 0.404067
# [135]	valid_0's binary_logloss: 0.404019
# [136]	valid_0's binary_logloss: 0.403988
# [137]	valid_0's binary_logloss: 0.403965
# [138]	valid_0's binary_logloss: 0.403943
# [139]	valid_0's binary_logloss: 0.403902
# [140]	valid_0's binary_logloss: 0.403877
# [141]	valid_0's binary_logloss: 0.403844
# [142]	valid_0's binary_logloss: 0.403818
# [143]	valid_0's binary_logloss: 0.403806
# [144]	valid_0's binary_logloss: 0.403781
# [145]	valid_0's binary_logloss: 0.40377
# [146]	valid_0's binary_logloss: 0.403763
# [147]	valid_0's binary_logloss: 0.40375
# [148]	valid_0's binary_logloss: 0.403736
# [149]	valid_0's binary_logloss: 0.403728
# [150]	valid_0's binary_logloss: 0.403722
# [151]	valid_0's binary_logloss: 0.403686
# [152]	valid_0's binary_logloss: 0.403671
# [153]	valid_0's binary_logloss: 0.40361
# [154]	valid_0's binary_logloss: 0.403594
# [155]	valid_0's binary_logloss: 0.403582
# [156]	valid_0's binary_logloss: 0.403564
# [157]	valid_0's binary_logloss: 0.403533
# [158]	valid_0's binary_logloss: 0.403513
# [159]	valid_0's binary_logloss: 0.403486
# [160]	valid_0's binary_logloss: 0.40348
# [161]	valid_0's binary_logloss: 0.403444
# [162]	valid_0's binary_logloss: 0.403432
# [163]	valid_0's binary_logloss: 0.403377
# [164]	valid_0's binary_logloss: 0.403347
# [165]	valid_0's binary_logloss: 0.40327
# [166]	valid_0's binary_logloss: 0.403224
# [167]	valid_0's binary_logloss: 0.403201
# [168]	valid_0's binary_logloss: 0.403193
# [169]	valid_0's binary_logloss: 0.403181
# [170]	valid_0's binary_logloss: 0.403174
# [171]	valid_0's binary_logloss: 0.403166
# [172]	valid_0's binary_logloss: 0.403159
# [173]	valid_0's binary_logloss: 0.403136
# [174]	valid_0's binary_logloss: 0.403139
# [175]	valid_0's binary_logloss: 0.403144
# [176]	valid_0's binary_logloss: 0.403141
# [177]	valid_0's binary_logloss: 0.403125
# [178]	valid_0's binary_logloss: 0.403101
# [179]	valid_0's binary_logloss: 0.40306
# [180]	valid_0's binary_logloss: 0.403049
# [181]	valid_0's binary_logloss: 0.403023
# [182]	valid_0's binary_logloss: 0.403009
# [183]	valid_0's binary_logloss: 0.403005
# [184]	valid_0's binary_logloss: 0.402987
# [185]	valid_0's binary_logloss: 0.402978
# [186]	valid_0's binary_logloss: 0.402965
# [187]	valid_0's binary_logloss: 0.40295
# [188]	valid_0's binary_logloss: 0.402934
# [189]	valid_0's binary_logloss: 0.402936
# [190]	valid_0's binary_logloss: 0.402932
# [191]	valid_0's binary_logloss: 0.402918
# [192]	valid_0's binary_logloss: 0.402895
# [193]	valid_0's binary_logloss: 0.402873
# [194]	valid_0's binary_logloss: 0.402857
# [195]	valid_0's binary_logloss: 0.402853
# [196]	valid_0's binary_logloss: 0.402784
# [197]	valid_0's binary_logloss: 0.402761
# [198]	valid_0's binary_logloss: 0.402711
# [199]	valid_0's binary_logloss: 0.40269
# [200]	valid_0's binary_logloss: 0.40268
# [201]	valid_0's binary_logloss: 0.402665
# [202]	valid_0's binary_logloss: 0.402663
# [203]	valid_0's binary_logloss: 0.402647
# [204]	valid_0's binary_logloss: 0.402629
# [205]	valid_0's binary_logloss: 0.402619
# [206]	valid_0's binary_logloss: 0.402587
# [207]	valid_0's binary_logloss: 0.402573
# [208]	valid_0's binary_logloss: 0.402564
# [209]	valid_0's binary_logloss: 0.402561
# [210]	valid_0's binary_logloss: 0.402558
# [211]	valid_0's binary_logloss: 0.402552
# [212]	valid_0's binary_logloss: 0.402554
# [213]	valid_0's binary_logloss: 0.402552
# [214]	valid_0's binary_logloss: 0.402528
# [215]	valid_0's binary_logloss: 0.402505
# [216]	valid_0's binary_logloss: 0.402502
# [217]	valid_0's binary_logloss: 0.402475
# [218]	valid_0's binary_logloss: 0.402463
# [219]	valid_0's binary_logloss: 0.402464
# [220]	valid_0's binary_logloss: 0.402473
# [221]	valid_0's binary_logloss: 0.402469
# [222]	valid_0's binary_logloss: 0.402472
# [223]	valid_0's binary_logloss: 0.402441
# [224]	valid_0's binary_logloss: 0.40244
# [225]	valid_0's binary_logloss: 0.402425
# [226]	valid_0's binary_logloss: 0.402406
# [227]	valid_0's binary_logloss: 0.402368
# [228]	valid_0's binary_logloss: 0.402354
# [229]	valid_0's binary_logloss: 0.402337
# [230]	valid_0's binary_logloss: 0.40233
# [231]	valid_0's binary_logloss: 0.402315
# [232]	valid_0's binary_logloss: 0.402295
# [233]	valid_0's binary_logloss: 0.402279
# [234]	valid_0's binary_logloss: 0.402266
# [235]	valid_0's binary_logloss: 0.402268
# [236]	valid_0's binary_logloss: 0.402256
# [237]	valid_0's binary_logloss: 0.40225
# [238]	valid_0's binary_logloss: 0.402232
# [239]	valid_0's binary_logloss: 0.402197
# [240]	valid_0's binary_logloss: 0.402193
# [241]	valid_0's binary_logloss: 0.402175
# [242]	valid_0's binary_logloss: 0.402159
# [243]	valid_0's binary_logloss: 0.402119
# [244]	valid_0's binary_logloss: 0.402112
# [245]	valid_0's binary_logloss: 0.4021
# [246]	valid_0's binary_logloss: 0.402078
# [247]	valid_0's binary_logloss: 0.402039
# [248]	valid_0's binary_logloss: 0.402019
# [249]	valid_0's binary_logloss: 0.402012
# [250]	valid_0's binary_logloss: 0.402008
# [251]	valid_0's binary_logloss: 0.402005
# [252]	valid_0's binary_logloss: 0.402
# [253]	valid_0's binary_logloss: 0.401995
# [254]	valid_0's binary_logloss: 0.401994
# [255]	valid_0's binary_logloss: 0.401998
# [256]	valid_0's binary_logloss: 0.401999
# [257]	valid_0's binary_logloss: 0.401999
# [258]	valid_0's binary_logloss: 0.401997
# [259]	valid_0's binary_logloss: 0.401984
# [260]	valid_0's binary_logloss: 0.401974
# [261]	valid_0's binary_logloss: 0.401947
# [262]	valid_0's binary_logloss: 0.401929
# [263]	valid_0's binary_logloss: 0.401911
# [264]	valid_0's binary_logloss: 0.401906
# [265]	valid_0's binary_logloss: 0.40189
# [266]	valid_0's binary_logloss: 0.401878
# [267]	valid_0's binary_logloss: 0.401879
# [268]	valid_0's binary_logloss: 0.401863
# [269]	valid_0's binary_logloss: 0.401848
# [270]	valid_0's binary_logloss: 0.401857
# [271]	valid_0's binary_logloss: 0.401851
# [272]	valid_0's binary_logloss: 0.401832
# [273]	valid_0's binary_logloss: 0.40181
# [274]	valid_0's binary_logloss: 0.401797
# [275]	valid_0's binary_logloss: 0.401794
# [276]	valid_0's binary_logloss: 0.401797
# [277]	valid_0's binary_logloss: 0.401775
# [278]	valid_0's binary_logloss: 0.401771
# [279]	valid_0's binary_logloss: 0.401742
# [280]	valid_0's binary_logloss: 0.401732
# [281]	valid_0's binary_logloss: 0.40173
# [282]	valid_0's binary_logloss: 0.401722
# [283]	valid_0's binary_logloss: 0.40172
# [284]	valid_0's binary_logloss: 0.401719
# [285]	valid_0's binary_logloss: 0.40172
# [286]	valid_0's binary_logloss: 0.401699
# [287]	valid_0's binary_logloss: 0.401667
# [288]	valid_0's binary_logloss: 0.401672
# [289]	valid_0's binary_logloss: 0.40166
# [290]	valid_0's binary_logloss: 0.401656
# [291]	valid_0's binary_logloss: 0.401637
# [292]	valid_0's binary_logloss: 0.401631
# [293]	valid_0's binary_logloss: 0.401623
# [294]	valid_0's binary_logloss: 0.401618
# [295]	valid_0's binary_logloss: 0.401608
# [296]	valid_0's binary_logloss: 0.401604
# [297]	valid_0's binary_logloss: 0.40161
# [298]	valid_0's binary_logloss: 0.401602
# [299]	valid_0's binary_logloss: 0.401604
# [300]	valid_0's binary_logloss: 0.401598
# [301]	valid_0's binary_logloss: 0.401592
# [302]	valid_0's binary_logloss: 0.401581
# [303]	valid_0's binary_logloss: 0.401562
# [304]	valid_0's binary_logloss: 0.40156
# [305]	valid_0's binary_logloss: 0.401558
# [306]	valid_0's binary_logloss: 0.401558
# [307]	valid_0's binary_logloss: 0.401548
# [308]	valid_0's binary_logloss: 0.401541
# [309]	valid_0's binary_logloss: 0.40154
# [310]	valid_0's binary_logloss: 0.401549
# [311]	valid_0's binary_logloss: 0.401548
# [312]	valid_0's binary_logloss: 0.401547
# [313]	valid_0's binary_logloss: 0.401543
# [314]	valid_0's binary_logloss: 0.401541
# [315]	valid_0's binary_logloss: 0.401545
# [316]	valid_0's binary_logloss: 0.401546
# [317]	valid_0's binary_logloss: 0.401544
# [318]	valid_0's binary_logloss: 0.401537
# [319]	valid_0's binary_logloss: 0.401554
# [320]	valid_0's binary_logloss: 0.401559
# [321]	valid_0's binary_logloss: 0.401568
# [322]	valid_0's binary_logloss: 0.401572
# [323]	valid_0's binary_logloss: 0.401564
# [324]	valid_0's binary_logloss: 0.401551
# [325]	valid_0's binary_logloss: 0.401558
# [326]	valid_0's binary_logloss: 0.40154
# [327]	valid_0's binary_logloss: 0.40152
# [328]	valid_0's binary_logloss: 0.401517
# [329]	valid_0's binary_logloss: 0.401518
# [330]	valid_0's binary_logloss: 0.401491
# [331]	valid_0's binary_logloss: 0.401478
# [332]	valid_0's binary_logloss: 0.401466
# [333]	valid_0's binary_logloss: 0.401459
# [334]	valid_0's binary_logloss: 0.401456
# [335]	valid_0's binary_logloss: 0.401458
# [336]	valid_0's binary_logloss: 0.401444
# [337]	valid_0's binary_logloss: 0.401441
# [338]	valid_0's binary_logloss: 0.401436
# [339]	valid_0's binary_logloss: 0.401443
# [340]	valid_0's binary_logloss: 0.401444
# [341]	valid_0's binary_logloss: 0.401427
# [342]	valid_0's binary_logloss: 0.40143
# [343]	valid_0's binary_logloss: 0.401418
# [344]	valid_0's binary_logloss: 0.401417
# [345]	valid_0's binary_logloss: 0.401407
# [346]	valid_0's binary_logloss: 0.401406
# [347]	valid_0's binary_logloss: 0.401406
# [348]	valid_0's binary_logloss: 0.401394
# [349]	valid_0's binary_logloss: 0.401391
# [350]	valid_0's binary_logloss: 0.401383
# [351]	valid_0's binary_logloss: 0.401364
# [352]	valid_0's binary_logloss: 0.401355
# [353]	valid_0's binary_logloss: 0.401347
# [354]	valid_0's binary_logloss: 0.401346
# [355]	valid_0's binary_logloss: 0.401341
# [356]	valid_0's binary_logloss: 0.401333
# [357]	valid_0's binary_logloss: 0.401326
# [358]	valid_0's binary_logloss: 0.401317
# [359]	valid_0's binary_logloss: 0.401301
# [360]	valid_0's binary_logloss: 0.401281
# [361]	valid_0's binary_logloss: 0.401282
# [362]	valid_0's binary_logloss: 0.401291
# [363]	valid_0's binary_logloss: 0.401304
# [364]	valid_0's binary_logloss: 0.401291
# [365]	valid_0's binary_logloss: 0.401258
# [366]	valid_0's binary_logloss: 0.401248
# [367]	valid_0's binary_logloss: 0.401235
# [368]	valid_0's binary_logloss: 0.40122
# [369]	valid_0's binary_logloss: 0.401221
# [370]	valid_0's binary_logloss: 0.401217
# [371]	valid_0's binary_logloss: 0.401206
# [372]	valid_0's binary_logloss: 0.401202
# [373]	valid_0's binary_logloss: 0.401193
# [374]	valid_0's binary_logloss: 0.401189
# [375]	valid_0's binary_logloss: 0.401187
# [376]	valid_0's binary_logloss: 0.401176
# [377]	valid_0's binary_logloss: 0.40115
# [378]	valid_0's binary_logloss: 0.401144
# [379]	valid_0's binary_logloss: 0.401135
# [380]	valid_0's binary_logloss: 0.401112
# [381]	valid_0's binary_logloss: 0.401101
# [382]	valid_0's binary_logloss: 0.401113
# [383]	valid_0's binary_logloss: 0.401112
# [384]	valid_0's binary_logloss: 0.401113
# [385]	valid_0's binary_logloss: 0.401106
# [386]	valid_0's binary_logloss: 0.401108
# [387]	valid_0's binary_logloss: 0.401098
# [388]	valid_0's binary_logloss: 0.401106
# [389]	valid_0's binary_logloss: 0.401104
# [390]	valid_0's binary_logloss: 0.401103
# [391]	valid_0's binary_logloss: 0.401102
# [392]	valid_0's binary_logloss: 0.401099
# [393]	valid_0's binary_logloss: 0.401099
# [394]	valid_0's binary_logloss: 0.401102
# [395]	valid_0's binary_logloss: 0.401103
# [396]	valid_0's binary_logloss: 0.401095
# [397]	valid_0's binary_logloss: 0.401087
# [398]	valid_0's binary_logloss: 0.401092
# [399]	valid_0's binary_logloss: 0.401084
# [400]	valid_0's binary_logloss: 0.401082
# [401]	valid_0's binary_logloss: 0.401074
# [402]	valid_0's binary_logloss: 0.401067
# [403]	valid_0's binary_logloss: 0.401076
# [404]	valid_0's binary_logloss: 0.401083
# [405]	valid_0's binary_logloss: 0.401082
# [406]	valid_0's binary_logloss: 0.401065
# [407]	valid_0's binary_logloss: 0.401064
# [408]	valid_0's binary_logloss: 0.401057
# [409]	valid_0's binary_logloss: 0.401043
# [410]	valid_0's binary_logloss: 0.401048
# [411]	valid_0's binary_logloss: 0.401041
# [412]	valid_0's binary_logloss: 0.401027
# [413]	valid_0's binary_logloss: 0.401028
# [414]	valid_0's binary_logloss: 0.401031
# [415]	valid_0's binary_logloss: 0.401027
# [416]	valid_0's binary_logloss: 0.401012
# [417]	valid_0's binary_logloss: 0.401017
# [418]	valid_0's binary_logloss: 0.401008
# [419]	valid_0's binary_logloss: 0.400988
# [420]	valid_0's binary_logloss: 0.400988
# [421]	valid_0's binary_logloss: 0.400989
# [422]	valid_0's binary_logloss: 0.400977
# [423]	valid_0's binary_logloss: 0.400977
# [424]	valid_0's binary_logloss: 0.400972
# [425]	valid_0's binary_logloss: 0.400965
# [426]	valid_0's binary_logloss: 0.400975
# [427]	valid_0's binary_logloss: 0.40097
# [428]	valid_0's binary_logloss: 0.400971
# [429]	valid_0's binary_logloss: 0.400975
# [430]	valid_0's binary_logloss: 0.400971
# [431]	valid_0's binary_logloss: 0.400974
# [432]	valid_0's binary_logloss: 0.400976
# [433]	valid_0's binary_logloss: 0.400975
# [434]	valid_0's binary_logloss: 0.400967
# [435]	valid_0's binary_logloss: 0.400959
# [436]	valid_0's binary_logloss: 0.400954
# [437]	valid_0's binary_logloss: 0.400954
# [438]	valid_0's binary_logloss: 0.400954
# [439]	valid_0's binary_logloss: 0.400954
# [440]	valid_0's binary_logloss: 0.400949
# [441]	valid_0's binary_logloss: 0.400944
# [442]	valid_0's binary_logloss: 0.400942
# [443]	valid_0's binary_logloss: 0.400939
# [444]	valid_0's binary_logloss: 0.40094
# [445]	valid_0's binary_logloss: 0.400934
# [446]	valid_0's binary_logloss: 0.400932
# [447]	valid_0's binary_logloss: 0.400917
# [448]	valid_0's binary_logloss: 0.400917
# [449]	valid_0's binary_logloss: 0.400917
# [450]	valid_0's binary_logloss: 0.400911
# [451]	valid_0's binary_logloss: 0.400904
# [452]	valid_0's binary_logloss: 0.400908
# [453]	valid_0's binary_logloss: 0.40091
# [454]	valid_0's binary_logloss: 0.400918
# [455]	valid_0's binary_logloss: 0.400909
# [456]	valid_0's binary_logloss: 0.400903
# [457]	valid_0's binary_logloss: 0.400895
# [458]	valid_0's binary_logloss: 0.400885
# [459]	valid_0's binary_logloss: 0.400883
# [460]	valid_0's binary_logloss: 0.400873
# [461]	valid_0's binary_logloss: 0.400867
# [462]	valid_0's binary_logloss: 0.400866
# [463]	valid_0's binary_logloss: 0.400867
# [464]	valid_0's binary_logloss: 0.400861
# [465]	valid_0's binary_logloss: 0.400851
# [466]	valid_0's binary_logloss: 0.400851
# [467]	valid_0's binary_logloss: 0.400829
# [468]	valid_0's binary_logloss: 0.40082
# [469]	valid_0's binary_logloss: 0.400824
# [470]	valid_0's binary_logloss: 0.400808
# [471]	valid_0's binary_logloss: 0.400802
# [472]	valid_0's binary_logloss: 0.400798
# [473]	valid_0's binary_logloss: 0.400794
# [474]	valid_0's binary_logloss: 0.400788
# [475]	valid_0's binary_logloss: 0.400775
# [476]	valid_0's binary_logloss: 0.400768
# [477]	valid_0's binary_logloss: 0.400765
# [478]	valid_0's binary_logloss: 0.400769
# [479]	valid_0's binary_logloss: 0.400766
# [480]	valid_0's binary_logloss: 0.40076
# [481]	valid_0's binary_logloss: 0.400761
# [482]	valid_0's binary_logloss: 0.400754
# [483]	valid_0's binary_logloss: 0.400738
# [484]	valid_0's binary_logloss: 0.400737
# [485]	valid_0's binary_logloss: 0.400742
# [486]	valid_0's binary_logloss: 0.400735
# [487]	valid_0's binary_logloss: 0.400732
# [488]	valid_0's binary_logloss: 0.400731
# [489]	valid_0's binary_logloss: 0.400724
# [490]	valid_0's binary_logloss: 0.400722
# [491]	valid_0's binary_logloss: 0.400724
# [492]	valid_0's binary_logloss: 0.400725
# [493]	valid_0's binary_logloss: 0.400727
# [494]	valid_0's binary_logloss: 0.400719
# [495]	valid_0's binary_logloss: 0.400725
# [496]	valid_0's binary_logloss: 0.400729
# [497]	valid_0's binary_logloss: 0.400733
# [498]	valid_0's binary_logloss: 0.400726
# [499]	valid_0's binary_logloss: 0.400715
# [500]	valid_0's binary_logloss: 0.400726
# [501]	valid_0's binary_logloss: 0.400726
# [502]	valid_0's binary_logloss: 0.400729
# [503]	valid_0's binary_logloss: 0.400734
# [504]	valid_0's binary_logloss: 0.400724
# [505]	valid_0's binary_logloss: 0.400725
# [506]	valid_0's binary_logloss: 0.400731
# [507]	valid_0's binary_logloss: 0.400724
# [508]	valid_0's binary_logloss: 0.400712
# [509]	valid_0's binary_logloss: 0.40071
# [510]	valid_0's binary_logloss: 0.400713
# [511]	valid_0's binary_logloss: 0.400709
# [512]	valid_0's binary_logloss: 0.400711
# [513]	valid_0's binary_logloss: 0.400715
# [514]	valid_0's binary_logloss: 0.400711
# [515]	valid_0's binary_logloss: 0.400704
# [516]	valid_0's binary_logloss: 0.400697
# [517]	valid_0's binary_logloss: 0.400687
# [518]	valid_0's binary_logloss: 0.400678
# [519]	valid_0's binary_logloss: 0.400672
# [520]	valid_0's binary_logloss: 0.400666
# [521]	valid_0's binary_logloss: 0.40066
# [522]	valid_0's binary_logloss: 0.400655
# [523]	valid_0's binary_logloss: 0.400645
# [524]	valid_0's binary_logloss: 0.400647
# [525]	valid_0's binary_logloss: 0.400646
# [526]	valid_0's binary_logloss: 0.400642
# [527]	valid_0's binary_logloss: 0.400632
# [528]	valid_0's binary_logloss: 0.400618
# [529]	valid_0's binary_logloss: 0.400626
# [530]	valid_0's binary_logloss: 0.400615
# [531]	valid_0's binary_logloss: 0.400603
# [532]	valid_0's binary_logloss: 0.400604
# [533]	valid_0's binary_logloss: 0.400599
# [534]	valid_0's binary_logloss: 0.400596
# [535]	valid_0's binary_logloss: 0.400598
# [536]	valid_0's binary_logloss: 0.400593
# [537]	valid_0's binary_logloss: 0.400586
# [538]	valid_0's binary_logloss: 0.400583
# [539]	valid_0's binary_logloss: 0.400582
# [540]	valid_0's binary_logloss: 0.400578
# [541]	valid_0's binary_logloss: 0.400574
# [542]	valid_0's binary_logloss: 0.400573
# [543]	valid_0's binary_logloss: 0.400576
# [544]	valid_0's binary_logloss: 0.40057
# [545]	valid_0's binary_logloss: 0.400574
# [546]	valid_0's binary_logloss: 0.400556
# [547]	valid_0's binary_logloss: 0.400552
# [548]	valid_0's binary_logloss: 0.400551
# [549]	valid_0's binary_logloss: 0.400567
# [550]	valid_0's binary_logloss: 0.400561
# [551]	valid_0's binary_logloss: 0.400562
# [552]	valid_0's binary_logloss: 0.400567
# [553]	valid_0's binary_logloss: 0.40058
# [554]	valid_0's binary_logloss: 0.400585
# [555]	valid_0's binary_logloss: 0.400597
# [556]	valid_0's binary_logloss: 0.400593
# [557]	valid_0's binary_logloss: 0.400588
# [558]	valid_0's binary_logloss: 0.400587
# [559]	valid_0's binary_logloss: 0.400583
# [560]	valid_0's binary_logloss: 0.400581
# [561]	valid_0's binary_logloss: 0.400577
# [562]	valid_0's binary_logloss: 0.400565
# [563]	valid_0's binary_logloss: 0.400568
# [564]	valid_0's binary_logloss: 0.400574
# [565]	valid_0's binary_logloss: 0.400575
# [566]	valid_0's binary_logloss: 0.400577
# [567]	valid_0's binary_logloss: 0.400574
# [568]	valid_0's binary_logloss: 0.40057
# [569]	valid_0's binary_logloss: 0.400559
# [570]	valid_0's binary_logloss: 0.400555
# [571]	valid_0's binary_logloss: 0.400555
# [572]	valid_0's binary_logloss: 0.400559
# [573]	valid_0's binary_logloss: 0.400564
# [574]	valid_0's binary_logloss: 0.400568
# [575]	valid_0's binary_logloss: 0.400573
# [576]	valid_0's binary_logloss: 0.400569
# [577]	valid_0's binary_logloss: 0.400569
# [578]	valid_0's binary_logloss: 0.400564
# [579]	valid_0's binary_logloss: 0.400555
# [580]	valid_0's binary_logloss: 0.400548
# [581]	valid_0's binary_logloss: 0.400549
# [582]	valid_0's binary_logloss: 0.40053
# [583]	valid_0's binary_logloss: 0.400534
# [584]	valid_0's binary_logloss: 0.400542
# [585]	valid_0's binary_logloss: 0.400545
# [586]	valid_0's binary_logloss: 0.400545
# [587]	valid_0's binary_logloss: 0.400546
# [588]	valid_0's binary_logloss: 0.400536
# [589]	valid_0's binary_logloss: 0.400536
# [590]	valid_0's binary_logloss: 0.400537
# [591]	valid_0's binary_logloss: 0.400525
# [592]	valid_0's binary_logloss: 0.400531
# [593]	valid_0's binary_logloss: 0.400512
# [594]	valid_0's binary_logloss: 0.400508
# [595]	valid_0's binary_logloss: 0.400515
# [596]	valid_0's binary_logloss: 0.400514
# [597]	valid_0's binary_logloss: 0.400518
# [598]	valid_0's binary_logloss: 0.400518
# [599]	valid_0's binary_logloss: 0.400498
# [600]	valid_0's binary_logloss: 0.4005
# [601]	valid_0's binary_logloss: 0.400487
# [602]	valid_0's binary_logloss: 0.400475
# [603]	valid_0's binary_logloss: 0.400475
# [604]	valid_0's binary_logloss: 0.400466
# [605]	valid_0's binary_logloss: 0.400466
# [606]	valid_0's binary_logloss: 0.400458
# [607]	valid_0's binary_logloss: 0.40045
# [608]	valid_0's binary_logloss: 0.40045
# [609]	valid_0's binary_logloss: 0.400457
# [610]	valid_0's binary_logloss: 0.400461
# [611]	valid_0's binary_logloss: 0.400462
# [612]	valid_0's binary_logloss: 0.400464
# [613]	valid_0's binary_logloss: 0.400459
# [614]	valid_0's binary_logloss: 0.40045
# [615]	valid_0's binary_logloss: 0.400456
# [616]	valid_0's binary_logloss: 0.400451
# [617]	valid_0's binary_logloss: 0.400448
# [618]	valid_0's binary_logloss: 0.400459
# [619]	valid_0's binary_logloss: 0.40046
# [620]	valid_0's binary_logloss: 0.400455
# [621]	valid_0's binary_logloss: 0.400443
# [622]	valid_0's binary_logloss: 0.400431
# [623]	valid_0's binary_logloss: 0.400429
# [624]	valid_0's binary_logloss: 0.40043
# [625]	valid_0's binary_logloss: 0.400437
# [626]	valid_0's binary_logloss: 0.400445
# [627]	valid_0's binary_logloss: 0.400453
# [628]	valid_0's binary_logloss: 0.400459
# [629]	valid_0's binary_logloss: 0.400473
# [630]	valid_0's binary_logloss: 0.400478
# [631]	valid_0's binary_logloss: 0.400472
# [632]	valid_0's binary_logloss: 0.400471
# [633]	valid_0's binary_logloss: 0.40047
# [634]	valid_0's binary_logloss: 0.400464
# [635]	valid_0's binary_logloss: 0.400448
# [636]	valid_0's binary_logloss: 0.400452
# [637]	valid_0's binary_logloss: 0.400441
# [638]	valid_0's binary_logloss: 0.400439
# [639]	valid_0's binary_logloss: 0.400435
# [640]	valid_0's binary_logloss: 0.400435
# [641]	valid_0's binary_logloss: 0.400428
# [642]	valid_0's binary_logloss: 0.400421
# [643]	valid_0's binary_logloss: 0.400425
# [644]	valid_0's binary_logloss: 0.400431
# [645]	valid_0's binary_logloss: 0.400421
# [646]	valid_0's binary_logloss: 0.400429
# [647]	valid_0's binary_logloss: 0.400424
# [648]	valid_0's binary_logloss: 0.400415
# [649]	valid_0's binary_logloss: 0.40042
# [650]	valid_0's binary_logloss: 0.400417
# [651]	valid_0's binary_logloss: 0.400417
# [652]	valid_0's binary_logloss: 0.400417
# [653]	valid_0's binary_logloss: 0.400419
# [654]	valid_0's binary_logloss: 0.400426
# [655]	valid_0's binary_logloss: 0.400434
# [656]	valid_0's binary_logloss: 0.400434
# [657]	valid_0's binary_logloss: 0.400429
# [658]	valid_0's binary_logloss: 0.400428
# [659]	valid_0's binary_logloss: 0.40043
# [660]	valid_0's binary_logloss: 0.400421
# [661]	valid_0's binary_logloss: 0.400419
# [662]	valid_0's binary_logloss: 0.400423
# [663]	valid_0's binary_logloss: 0.400421
# [664]	valid_0's binary_logloss: 0.400432
# [665]	valid_0's binary_logloss: 0.400434
# [666]	valid_0's binary_logloss: 0.400438
# [667]	valid_0's binary_logloss: 0.400442
# [668]	valid_0's binary_logloss: 0.400446
# [669]	valid_0's binary_logloss: 0.400435
# [670]	valid_0's binary_logloss: 0.400433
# [671]	valid_0's binary_logloss: 0.400432
# [672]	valid_0's binary_logloss: 0.400439
# [673]	valid_0's binary_logloss: 0.400419
# [674]	valid_0's binary_logloss: 0.400414
# [675]	valid_0's binary_logloss: 0.400417
# [676]	valid_0's binary_logloss: 0.40041
# [677]	valid_0's binary_logloss: 0.400414
# [678]	valid_0's binary_logloss: 0.400417
# [679]	valid_0's binary_logloss: 0.400426
# [680]	valid_0's binary_logloss: 0.40043
# [681]	valid_0's binary_logloss: 0.400435
# [682]	valid_0's binary_logloss: 0.400438
# [683]	valid_0's binary_logloss: 0.400446
# [684]	valid_0's binary_logloss: 0.400439
# [685]	valid_0's binary_logloss: 0.400441
# [686]	valid_0's binary_logloss: 0.400439
# [687]	valid_0's binary_logloss: 0.400443
# [688]	valid_0's binary_logloss: 0.400444
# [689]	valid_0's binary_logloss: 0.400445
# [690]	valid_0's binary_logloss: 0.400441
# [691]	valid_0's binary_logloss: 0.400448
# [692]	valid_0's binary_logloss: 0.40044
# [693]	valid_0's binary_logloss: 0.400444
# [694]	valid_0's binary_logloss: 0.400444
# [695]	valid_0's binary_logloss: 0.40045
# [696]	valid_0's binary_logloss: 0.400443
# [697]	valid_0's binary_logloss: 0.400437
# [698]	valid_0's binary_logloss: 0.400439
# [699]	valid_0's binary_logloss: 0.400433
# [700]	valid_0's binary_logloss: 0.400444
# [701]	valid_0's binary_logloss: 0.400427
# [702]	valid_0's binary_logloss: 0.400427
# [703]	valid_0's binary_logloss: 0.400435
# [704]	valid_0's binary_logloss: 0.400428
# [705]	valid_0's binary_logloss: 0.400424
# [706]	valid_0's binary_logloss: 0.400431
# [707]	valid_0's binary_logloss: 0.400427
# [708]	valid_0's binary_logloss: 0.400421
# [709]	valid_0's binary_logloss: 0.400428
# [710]	valid_0's binary_logloss: 0.400432
# [711]	valid_0's binary_logloss: 0.400428
# [712]	valid_0's binary_logloss: 0.400426
# [713]	valid_0's binary_logloss: 0.400423
# [714]	valid_0's binary_logloss: 0.400421
# [715]	valid_0's binary_logloss: 0.400421
# [716]	valid_0's binary_logloss: 0.400422
# [717]	valid_0's binary_logloss: 0.400423
# [718]	valid_0's binary_logloss: 0.400417
# [719]	valid_0's binary_logloss: 0.400408
# [720]	valid_0's binary_logloss: 0.400399
# [721]	valid_0's binary_logloss: 0.400393
# [722]	valid_0's binary_logloss: 0.400407
# [723]	valid_0's binary_logloss: 0.400414
# [724]	valid_0's binary_logloss: 0.400413
# [725]	valid_0's binary_logloss: 0.400409
# [726]	valid_0's binary_logloss: 0.400415
# [727]	valid_0's binary_logloss: 0.400408
# [728]	valid_0's binary_logloss: 0.400409
# [729]	valid_0's binary_logloss: 0.400416
# [730]	valid_0's binary_logloss: 0.40042
# [731]	valid_0's binary_logloss: 0.400415
# [732]	valid_0's binary_logloss: 0.400409
# [733]	valid_0's binary_logloss: 0.400406
# [734]	valid_0's binary_logloss: 0.400404
# [735]	valid_0's binary_logloss: 0.400412
# [736]	valid_0's binary_logloss: 0.400408
# [737]	valid_0's binary_logloss: 0.400396
# [738]	valid_0's binary_logloss: 0.400397
# [739]	valid_0's binary_logloss: 0.400392
# [740]	valid_0's binary_logloss: 0.400385
# [741]	valid_0's binary_logloss: 0.40038
# [742]	valid_0's binary_logloss: 0.400379
# [743]	valid_0's binary_logloss: 0.400353
# [744]	valid_0's binary_logloss: 0.400345
# [745]	valid_0's binary_logloss: 0.400342
# [746]	valid_0's binary_logloss: 0.400328
# [747]	valid_0's binary_logloss: 0.400321
# [748]	valid_0's binary_logloss: 0.400323
# [749]	valid_0's binary_logloss: 0.400311
# [750]	valid_0's binary_logloss: 0.400307
# [751]	valid_0's binary_logloss: 0.400322
# [752]	valid_0's binary_logloss: 0.400329
# [753]	valid_0's binary_logloss: 0.400326
# [754]	valid_0's binary_logloss: 0.400324
# [755]	valid_0's binary_logloss: 0.400329
# [756]	valid_0's binary_logloss: 0.400329
# [757]	valid_0's binary_logloss: 0.400315
# [758]	valid_0's binary_logloss: 0.400318
# [759]	valid_0's binary_logloss: 0.400326
# [760]	valid_0's binary_logloss: 0.400326
# [761]	valid_0's binary_logloss: 0.400327
# [762]	valid_0's binary_logloss: 0.40033
# [763]	valid_0's binary_logloss: 0.40032
# [764]	valid_0's binary_logloss: 0.40031
# [765]	valid_0's binary_logloss: 0.400304
# [766]	valid_0's binary_logloss: 0.400301
# [767]	valid_0's binary_logloss: 0.400305
# [768]	valid_0's binary_logloss: 0.400316
# [769]	valid_0's binary_logloss: 0.400318
# [770]	valid_0's binary_logloss: 0.400324
# [771]	valid_0's binary_logloss: 0.400319
# [772]	valid_0's binary_logloss: 0.400303
# [773]	valid_0's binary_logloss: 0.400302
# [774]	valid_0's binary_logloss: 0.400295
# [775]	valid_0's binary_logloss: 0.400292
# [776]	valid_0's binary_logloss: 0.400292
# [777]	valid_0's binary_logloss: 0.400288
# [778]	valid_0's binary_logloss: 0.400288
# [779]	valid_0's binary_logloss: 0.400297
# [780]	valid_0's binary_logloss: 0.4003
# [781]	valid_0's binary_logloss: 0.400293
# [782]	valid_0's binary_logloss: 0.400303
# [783]	valid_0's binary_logloss: 0.40031
# [784]	valid_0's binary_logloss: 0.400311
# [785]	valid_0's binary_logloss: 0.400318
# [786]	valid_0's binary_logloss: 0.400316
# [787]	valid_0's binary_logloss: 0.400325
# [788]	valid_0's binary_logloss: 0.400318
# [789]	valid_0's binary_logloss: 0.400324
# [790]	valid_0's binary_logloss: 0.400316
# [791]	valid_0's binary_logloss: 0.400316
# [792]	valid_0's binary_logloss: 0.400315
# [793]	valid_0's binary_logloss: 0.40031
# [794]	valid_0's binary_logloss: 0.400316
# [795]	valid_0's binary_logloss: 0.400312
# [796]	valid_0's binary_logloss: 0.400306
# [797]	valid_0's binary_logloss: 0.400314
# [798]	valid_0's binary_logloss: 0.40032
# [799]	valid_0's binary_logloss: 0.400324
# [800]	valid_0's binary_logloss: 0.400323
# [801]	valid_0's binary_logloss: 0.400323
# [802]	valid_0's binary_logloss: 0.400328
# [803]	valid_0's binary_logloss: 0.400323
# [804]	valid_0's binary_logloss: 0.400329
# [805]	valid_0's binary_logloss: 0.40033
# [806]	valid_0's binary_logloss: 0.400328
# [807]	valid_0's binary_logloss: 0.40033
# [808]	valid_0's binary_logloss: 0.400332
# [809]	valid_0's binary_logloss: 0.400337
# [810]	valid_0's binary_logloss: 0.400348
# [811]	valid_0's binary_logloss: 0.400346
# [812]	valid_0's binary_logloss: 0.400337
# [813]	valid_0's binary_logloss: 0.400337
# [814]	valid_0's binary_logloss: 0.400333
# [815]	valid_0's binary_logloss: 0.400331
# [816]	valid_0's binary_logloss: 0.400331
# [817]	valid_0's binary_logloss: 0.400331
# [818]	valid_0's binary_logloss: 0.400321
# [819]	valid_0's binary_logloss: 0.400308
# [820]	valid_0's binary_logloss: 0.400304
# [821]	valid_0's binary_logloss: 0.400304
# [822]	valid_0's binary_logloss: 0.400306
# [823]	valid_0's binary_logloss: 0.400304
# [824]	valid_0's binary_logloss: 0.400316
# [825]	valid_0's binary_logloss: 0.400314
# [826]	valid_0's binary_logloss: 0.400314
# [827]	valid_0's binary_logloss: 0.400313
# [828]	valid_0's binary_logloss: 0.400315
# [829]	valid_0's binary_logloss: 0.400313
# [830]	valid_0's binary_logloss: 0.400318
# [831]	valid_0's binary_logloss: 0.40032
# [832]	valid_0's binary_logloss: 0.400318
# [833]	valid_0's binary_logloss: 0.40032
# [834]	valid_0's binary_logloss: 0.400323
# [835]	valid_0's binary_logloss: 0.400322
# [836]	valid_0's binary_logloss: 0.400321
# [837]	valid_0's binary_logloss: 0.400327
# [838]	valid_0's binary_logloss: 0.400326
# [839]	valid_0's binary_logloss: 0.400332
# [840]	valid_0's binary_logloss: 0.400338
# [841]	valid_0's binary_logloss: 0.400338
# [842]	valid_0's binary_logloss: 0.40034
# [843]	valid_0's binary_logloss: 0.400333
# [844]	valid_0's binary_logloss: 0.400339
# [845]	valid_0's binary_logloss: 0.400341
# [846]	valid_0's binary_logloss: 0.400334
# [847]	valid_0's binary_logloss: 0.400321
# [848]	valid_0's binary_logloss: 0.400317
# [849]	valid_0's binary_logloss: 0.400323
# [850]	valid_0's binary_logloss: 0.40033
# [851]	valid_0's binary_logloss: 0.400335
# [852]	valid_0's binary_logloss: 0.400327
# [853]	valid_0's binary_logloss: 0.400318
# [854]	valid_0's binary_logloss: 0.400311
# [855]	valid_0's binary_logloss: 0.400312
# [856]	valid_0's binary_logloss: 0.400313
# [857]	valid_0's binary_logloss: 0.400303
# [858]	valid_0's binary_logloss: 0.400292
# [859]	valid_0's binary_logloss: 0.400294
# [860]	valid_0's binary_logloss: 0.400298
# [861]	valid_0's binary_logloss: 0.400296
# [862]	valid_0's binary_logloss: 0.400297
# [863]	valid_0's binary_logloss: 0.400297
# [864]	valid_0's binary_logloss: 0.400298
# [865]	valid_0's binary_logloss: 0.400302
# [866]	valid_0's binary_logloss: 0.400302
# [867]	valid_0's binary_logloss: 0.400296
# [868]	valid_0's binary_logloss: 0.400292
# [869]	valid_0's binary_logloss: 0.400294
# [870]	valid_0's binary_logloss: 0.400294
# [871]	valid_0's binary_logloss: 0.4003
# [872]	valid_0's binary_logloss: 0.400295
# [873]	valid_0's binary_logloss: 0.400299
# [874]	valid_0's binary_logloss: 0.400298
# [875]	valid_0's binary_logloss: 0.400291
# [876]	valid_0's binary_logloss: 0.400276
# [877]	valid_0's binary_logloss: 0.400282
# [878]	valid_0's binary_logloss: 0.400283
# [879]	valid_0's binary_logloss: 0.400277
# [880]	valid_0's binary_logloss: 0.400269
# [881]	valid_0's binary_logloss: 0.400269
# [882]	valid_0's binary_logloss: 0.400268
# [883]	valid_0's binary_logloss: 0.400266
# [884]	valid_0's binary_logloss: 0.400276
# [885]	valid_0's binary_logloss: 0.400278
# [886]	valid_0's binary_logloss: 0.400286
# [887]	valid_0's binary_logloss: 0.400289
# [888]	valid_0's binary_logloss: 0.400292
# [889]	valid_0's binary_logloss: 0.400295
# [890]	valid_0's binary_logloss: 0.400304
# [891]	valid_0's binary_logloss: 0.400315
# [892]	valid_0's binary_logloss: 0.400322
# [893]	valid_0's binary_logloss: 0.400332
# [894]	valid_0's binary_logloss: 0.400335
# [895]	valid_0's binary_logloss: 0.400341
# [896]	valid_0's binary_logloss: 0.400347
# [897]	valid_0's binary_logloss: 0.400345
# [898]	valid_0's binary_logloss: 0.400349
# [899]	valid_0's binary_logloss: 0.400344
# [900]	valid_0's binary_logloss: 0.40035
# [901]	valid_0's binary_logloss: 0.400338
# [902]	valid_0's binary_logloss: 0.400337
# [903]	valid_0's binary_logloss: 0.400333
# [904]	valid_0's binary_logloss: 0.400331
# [905]	valid_0's binary_logloss: 0.400335
# [906]	valid_0's binary_logloss: 0.400327
# [907]	valid_0's binary_logloss: 0.400319
# [908]	valid_0's binary_logloss: 0.400321
# [909]	valid_0's binary_logloss: 0.400321
# [910]	valid_0's binary_logloss: 0.400315
# [911]	valid_0's binary_logloss: 0.400323
# [912]	valid_0's binary_logloss: 0.400336
# [913]	valid_0's binary_logloss: 0.400341
# [914]	valid_0's binary_logloss: 0.400344
# [915]	valid_0's binary_logloss: 0.40035
# [916]	valid_0's binary_logloss: 0.400355
# [917]	valid_0's binary_logloss: 0.400343
# [918]	valid_0's binary_logloss: 0.400343
# [919]	valid_0's binary_logloss: 0.400345
# [920]	valid_0's binary_logloss: 0.400342
# [921]	valid_0's binary_logloss: 0.400347
# [922]	valid_0's binary_logloss: 0.400343
# [923]	valid_0's binary_logloss: 0.400354
# [924]	valid_0's binary_logloss: 0.400354
# [925]	valid_0's binary_logloss: 0.400355
# [926]	valid_0's binary_logloss: 0.400359
# [927]	valid_0's binary_logloss: 0.400362
# [928]	valid_0's binary_logloss: 0.400363
# [929]	valid_0's binary_logloss: 0.400368
# [930]	valid_0's binary_logloss: 0.400364
# [931]	valid_0's binary_logloss: 0.400357
# [932]	valid_0's binary_logloss: 0.400355
# [933]	valid_0's binary_logloss: 0.400353
# [934]	valid_0's binary_logloss: 0.400347
# [935]	valid_0's binary_logloss: 0.400341
# [936]	valid_0's binary_logloss: 0.40033
# [937]	valid_0's binary_logloss: 0.400319
# [938]	valid_0's binary_logloss: 0.400317
# [939]	valid_0's binary_logloss: 0.400311
# [940]	valid_0's binary_logloss: 0.400306
# [941]	valid_0's binary_logloss: 0.400301
# [942]	valid_0's binary_logloss: 0.400291
# [943]	valid_0's binary_logloss: 0.400297
# [944]	valid_0's binary_logloss: 0.400295
# [945]	valid_0's binary_logloss: 0.400282
# [946]	valid_0's binary_logloss: 0.400286
# [947]	valid_0's binary_logloss: 0.400286
# [948]	valid_0's binary_logloss: 0.400291
# [949]	valid_0's binary_logloss: 0.400298
# [950]	valid_0's binary_logloss: 0.400301
# [951]	valid_0's binary_logloss: 0.400307
# [952]	valid_0's binary_logloss: 0.400305
# [953]	valid_0's binary_logloss: 0.400307
# [954]	valid_0's binary_logloss: 0.400312
# [955]	valid_0's binary_logloss: 0.400317
# [956]	valid_0's binary_logloss: 0.400319
# [957]	valid_0's binary_logloss: 0.400321
# [958]	valid_0's binary_logloss: 0.400316
# [959]	valid_0's binary_logloss: 0.400324
# [960]	valid_0's binary_logloss: 0.400331
# [961]	valid_0's binary_logloss: 0.400324
# [962]	valid_0's binary_logloss: 0.400323
# [963]	valid_0's binary_logloss: 0.400327
# [964]	valid_0's binary_logloss: 0.40033
# [965]	valid_0's binary_logloss: 0.40033
# [966]	valid_0's binary_logloss: 0.400345
# [967]	valid_0's binary_logloss: 0.400354
# [968]	valid_0's binary_logloss: 0.400358
# [969]	valid_0's binary_logloss: 0.400365
# [970]	valid_0's binary_logloss: 0.400367
# [971]	valid_0's binary_logloss: 0.400375
# [972]	valid_0's binary_logloss: 0.400382
# [973]	valid_0's binary_logloss: 0.400388
# [974]	valid_0's binary_logloss: 0.400391
# [975]	valid_0's binary_logloss: 0.400385
# [976]	valid_0's binary_logloss: 0.400381
# [977]	valid_0's binary_logloss: 0.400375
# [978]	valid_0's binary_logloss: 0.400376
# [979]	valid_0's binary_logloss: 0.400387
# [980]	valid_0's binary_logloss: 0.400385
# [981]	valid_0's binary_logloss: 0.400376
# [982]	valid_0's binary_logloss: 0.400373
# [983]	valid_0's binary_logloss: 0.400371
# [984]	valid_0's binary_logloss: 0.400365
# [985]	valid_0's binary_logloss: 0.400369
# [986]	valid_0's binary_logloss: 0.40036
# [987]	valid_0's binary_logloss: 0.400367
# [988]	valid_0's binary_logloss: 0.400372
# [989]	valid_0's binary_logloss: 0.400373
# [990]	valid_0's binary_logloss: 0.400373
# [991]	valid_0's binary_logloss: 0.400367
# [992]	valid_0's binary_logloss: 0.400368
# [993]	valid_0's binary_logloss: 0.400368
# [994]	valid_0's binary_logloss: 0.400369
# [995]	valid_0's binary_logloss: 0.400369
# [996]	valid_0's binary_logloss: 0.400373
# [997]	valid_0's binary_logloss: 0.400378
# [998]	valid_0's binary_logloss: 0.400383
# [999]	valid_0's binary_logloss: 0.400391
# [1000]	valid_0's binary_logloss: 0.400388
# [1001]	valid_0's binary_logloss: 0.400384
# [1002]	valid_0's binary_logloss: 0.400394
# [1003]	valid_0's binary_logloss: 0.400394
# [1004]	valid_0's binary_logloss: 0.400391
# [1005]	valid_0's binary_logloss: 0.400391
# [1006]	valid_0's binary_logloss: 0.400392
# [1007]	valid_0's binary_logloss: 0.400388
# [1008]	valid_0's binary_logloss: 0.400378
# [1009]	valid_0's binary_logloss: 0.40038
# [1010]	valid_0's binary_logloss: 0.400382
# [1011]	valid_0's binary_logloss: 0.400387
# [1012]	valid_0's binary_logloss: 0.400394
# [1013]	valid_0's binary_logloss: 0.400401
# [1014]	valid_0's binary_logloss: 0.400406
# [1015]	valid_0's binary_logloss: 0.400411
# [1016]	valid_0's binary_logloss: 0.40042
# [1017]	valid_0's binary_logloss: 0.400424
# [1018]	valid_0's binary_logloss: 0.400423
# [1019]	valid_0's binary_logloss: 0.400436
# [1020]	valid_0's binary_logloss: 0.400442
# [1021]	valid_0's binary_logloss: 0.400449
# [1022]	valid_0's binary_logloss: 0.400445
# [1023]	valid_0's binary_logloss: 0.40043
# [1024]	valid_0's binary_logloss: 0.400425
# [1025]	valid_0's binary_logloss: 0.400417
# [1026]	valid_0's binary_logloss: 0.400416
# [1027]	valid_0's binary_logloss: 0.400417
# [1028]	valid_0's binary_logloss: 0.400416
# [1029]	valid_0's binary_logloss: 0.400419
# [1030]	valid_0's binary_logloss: 0.400422
# [1031]	valid_0's binary_logloss: 0.400421
# [1032]	valid_0's binary_logloss: 0.400415
# [1033]	valid_0's binary_logloss: 0.400416
# [1034]	valid_0's binary_logloss: 0.400416
# [1035]	valid_0's binary_logloss: 0.400416
# [1036]	valid_0's binary_logloss: 0.400411
# [1037]	valid_0's binary_logloss: 0.400411
# [1038]	valid_0's binary_logloss: 0.400416
# [1039]	valid_0's binary_logloss: 0.400421
# [1040]	valid_0's binary_logloss: 0.400432
# [1041]	valid_0's binary_logloss: 0.400433
# [1042]	valid_0's binary_logloss: 0.400429
# [1043]	valid_0's binary_logloss: 0.400433
# [1044]	valid_0's binary_logloss: 0.400435
# [1045]	valid_0's binary_logloss: 0.400434
# [1046]	valid_0's binary_logloss: 0.400438
# [1047]	valid_0's binary_logloss: 0.400435
# [1048]	valid_0's binary_logloss: 0.400441
# [1049]	valid_0's binary_logloss: 0.400446
# [1050]	valid_0's binary_logloss: 0.400455
# [1051]	valid_0's binary_logloss: 0.400448
# [1052]	valid_0's binary_logloss: 0.400457
# [1053]	valid_0's binary_logloss: 0.400458
# [1054]	valid_0's binary_logloss: 0.400452
# [1055]	valid_0's binary_logloss: 0.400454
# [1056]	valid_0's binary_logloss: 0.400448
# [1057]	valid_0's binary_logloss: 0.400451
# [1058]	valid_0's binary_logloss: 0.400453
# [1059]	valid_0's binary_logloss: 0.400452
# [1060]	valid_0's binary_logloss: 0.400442
# [1061]	valid_0's binary_logloss: 0.400443
# [1062]	valid_0's binary_logloss: 0.400449
# [1063]	valid_0's binary_logloss: 0.40045
# [1064]	valid_0's binary_logloss: 0.400451
# [1065]	valid_0's binary_logloss: 0.400451
# [1066]	valid_0's binary_logloss: 0.40045
# [1067]	valid_0's binary_logloss: 0.40046
# [1068]	valid_0's binary_logloss: 0.400455
# [1069]	valid_0's binary_logloss: 0.400466
# [1070]	valid_0's binary_logloss: 0.400472
# [1071]	valid_0's binary_logloss: 0.40047
# [1072]	valid_0's binary_logloss: 0.400472
# [1073]	valid_0's binary_logloss: 0.400476
# [1074]	valid_0's binary_logloss: 0.400483
# [1075]	valid_0's binary_logloss: 0.400494
# [1076]	valid_0's binary_logloss: 0.40049
# [1077]	valid_0's binary_logloss: 0.400486
# [1078]	valid_0's binary_logloss: 0.400487
# [1079]	valid_0's binary_logloss: 0.40049
# [1080]	valid_0's binary_logloss: 0.400487
# [1081]	valid_0's binary_logloss: 0.400485
# [1082]	valid_0's binary_logloss: 0.400478
# [1083]	valid_0's binary_logloss: 0.400466
# [1084]	valid_0's binary_logloss: 0.400461
# [1085]	valid_0's binary_logloss: 0.400453
# [1086]	valid_0's binary_logloss: 0.400452
# [1087]	valid_0's binary_logloss: 0.400463
# [1088]	valid_0's binary_logloss: 0.400468
# [1089]	valid_0's binary_logloss: 0.400472
# [1090]	valid_0's binary_logloss: 0.400475
# [1091]	valid_0's binary_logloss: 0.400474
# [1092]	valid_0's binary_logloss: 0.400478
# [1093]	valid_0's binary_logloss: 0.400489
# [1094]	valid_0's binary_logloss: 0.400495
# [1095]	valid_0's binary_logloss: 0.40049
# [1096]	valid_0's binary_logloss: 0.400493
# [1097]	valid_0's binary_logloss: 0.400491
# [1098]	valid_0's binary_logloss: 0.400492
# [1099]	valid_0's binary_logloss: 0.400492
# [1100]	valid_0's binary_logloss: 0.400493
# [1101]	valid_0's binary_logloss: 0.400493
# [1102]	valid_0's binary_logloss: 0.400489
# [1103]	valid_0's binary_logloss: 0.400482
# [1104]	valid_0's binary_logloss: 0.400488
# [1105]	valid_0's binary_logloss: 0.400482
# [1106]	valid_0's binary_logloss: 0.400481
# [1107]	valid_0's binary_logloss: 0.400484
# [1108]	valid_0's binary_logloss: 0.400473
# [1109]	valid_0's binary_logloss: 0.400483
# [1110]	valid_0's binary_logloss: 0.400488
# [1111]	valid_0's binary_logloss: 0.40048
# [1112]	valid_0's binary_logloss: 0.400474
# [1113]	valid_0's binary_logloss: 0.400476
# [1114]	valid_0's binary_logloss: 0.400479
# [1115]	valid_0's binary_logloss: 0.400475
# [1116]	valid_0's binary_logloss: 0.400465
# [1117]	valid_0's binary_logloss: 0.400464
# [1118]	valid_0's binary_logloss: 0.400465
# [1119]	valid_0's binary_logloss: 0.400458
# [1120]	valid_0's binary_logloss: 0.400459
# [1121]	valid_0's binary_logloss: 0.400453
# [1122]	valid_0's binary_logloss: 0.400447
# [1123]	valid_0's binary_logloss: 0.400449
# [1124]	valid_0's binary_logloss: 0.400439
# [1125]	valid_0's binary_logloss: 0.400438
# [1126]	valid_0's binary_logloss: 0.400442
# [1127]	valid_0's binary_logloss: 0.40044
# [1128]	valid_0's binary_logloss: 0.400455
# [1129]	valid_0's binary_logloss: 0.40045
# [1130]	valid_0's binary_logloss: 0.400457
# [1131]	valid_0's binary_logloss: 0.400462
# [1132]	valid_0's binary_logloss: 0.400459
# [1133]	valid_0's binary_logloss: 0.400458
# [1134]	valid_0's binary_logloss: 0.400465
# [1135]	valid_0's binary_logloss: 0.400464
# [1136]	valid_0's binary_logloss: 0.400463
# [1137]	valid_0's binary_logloss: 0.400453
# [1138]	valid_0's binary_logloss: 0.400464
# [1139]	valid_0's binary_logloss: 0.400468
# [1140]	valid_0's binary_logloss: 0.40047
# [1141]	valid_0's binary_logloss: 0.400471
# [1142]	valid_0's binary_logloss: 0.400467
# [1143]	valid_0's binary_logloss: 0.400478
# [1144]	valid_0's binary_logloss: 0.400483
# [1145]	valid_0's binary_logloss: 0.400476
# [1146]	valid_0's binary_logloss: 0.400478
# [1147]	valid_0's binary_logloss: 0.400481
# [1148]	valid_0's binary_logloss: 0.400487
# [1149]	valid_0's binary_logloss: 0.400488
# [1150]	valid_0's binary_logloss: 0.400484
# [1151]	valid_0's binary_logloss: 0.400483
# [1152]	valid_0's binary_logloss: 0.400492
# [1153]	valid_0's binary_logloss: 0.400499
# [1154]	valid_0's binary_logloss: 0.400492
# [1155]	valid_0's binary_logloss: 0.400492
# [1156]	valid_0's binary_logloss: 0.400493
# [1157]	valid_0's binary_logloss: 0.400497
# [1158]	valid_0's binary_logloss: 0.400505
# [1159]	valid_0's binary_logloss: 0.400494
# [1160]	valid_0's binary_logloss: 0.400492
# [1161]	valid_0's binary_logloss: 0.400504
# [1162]	valid_0's binary_logloss: 0.400496
# [1163]	valid_0's binary_logloss: 0.400492
# [1164]	valid_0's binary_logloss: 0.40049
# [1165]	valid_0's binary_logloss: 0.400487
# [1166]	valid_0's binary_logloss: 0.400486
# [1167]	valid_0's binary_logloss: 0.400484
# [1168]	valid_0's binary_logloss: 0.40048
# [1169]	valid_0's binary_logloss: 0.400485
# [1170]	valid_0's binary_logloss: 0.400492
# [1171]	valid_0's binary_logloss: 0.400495
# [1172]	valid_0's binary_logloss: 0.400488
# [1173]	valid_0's binary_logloss: 0.400501
# [1174]	valid_0's binary_logloss: 0.400507
# [1175]	valid_0's binary_logloss: 0.400511
# [1176]	valid_0's binary_logloss: 0.400518
# [1177]	valid_0's binary_logloss: 0.400521
# [1178]	valid_0's binary_logloss: 0.400527
# [1179]	valid_0's binary_logloss: 0.400524
# [1180]	valid_0's binary_logloss: 0.40053
# [1181]	valid_0's binary_logloss: 0.400538
# [1182]	valid_0's binary_logloss: 0.400542
# [1183]	valid_0's binary_logloss: 0.400545
# [1184]	valid_0's binary_logloss: 0.400544
# [1185]	valid_0's binary_logloss: 0.400548
# [1186]	valid_0's binary_logloss: 0.400561
# [1187]	valid_0's binary_logloss: 0.400562
# [1188]	valid_0's binary_logloss: 0.400576
# [1189]	valid_0's binary_logloss: 0.400583
# [1190]	valid_0's binary_logloss: 0.400575
# [1191]	valid_0's binary_logloss: 0.400579
# [1192]	valid_0's binary_logloss: 0.400585
# [1193]	valid_0's binary_logloss: 0.400586
# [1194]	valid_0's binary_logloss: 0.400601
# [1195]	valid_0's binary_logloss: 0.400607
# [1196]	valid_0's binary_logloss: 0.400604
# [1197]	valid_0's binary_logloss: 0.400598
# [1198]	valid_0's binary_logloss: 0.400599
# [1199]	valid_0's binary_logloss: 0.400595
# [1200]	valid_0's binary_logloss: 0.400605
# [1201]	valid_0's binary_logloss: 0.400616
# [1202]	valid_0's binary_logloss: 0.400626
# [1203]	valid_0's binary_logloss: 0.400625
# [1204]	valid_0's binary_logloss: 0.400636
# [1205]	valid_0's binary_logloss: 0.400644
# [1206]	valid_0's binary_logloss: 0.400649
# [1207]	valid_0's binary_logloss: 0.40065
# [1208]	valid_0's binary_logloss: 0.400637
# [1209]	valid_0's binary_logloss: 0.400638
# [1210]	valid_0's binary_logloss: 0.40064
# [1211]	valid_0's binary_logloss: 0.400644
# [1212]	valid_0's binary_logloss: 0.400644
# [1213]	valid_0's binary_logloss: 0.400645
# [1214]	valid_0's binary_logloss: 0.400647
# [1215]	valid_0's binary_logloss: 0.400642
# [1216]	valid_0's binary_logloss: 0.400641
# [1217]	valid_0's binary_logloss: 0.40063
# [1218]	valid_0's binary_logloss: 0.400611
# [1219]	valid_0's binary_logloss: 0.400619
# [1220]	valid_0's binary_logloss: 0.400618
# [1221]	valid_0's binary_logloss: 0.400616
# [1222]	valid_0's binary_logloss: 0.400615
# [1223]	valid_0's binary_logloss: 0.400608
# [1224]	valid_0's binary_logloss: 0.400605
# [1225]	valid_0's binary_logloss: 0.4006
# [1226]	valid_0's binary_logloss: 0.400608
# [1227]	valid_0's binary_logloss: 0.400616
# [1228]	valid_0's binary_logloss: 0.400614
# [1229]	valid_0's binary_logloss: 0.400614
# [1230]	valid_0's binary_logloss: 0.400612
# [1231]	valid_0's binary_logloss: 0.400615
# [1232]	valid_0's binary_logloss: 0.40062
# [1233]	valid_0's binary_logloss: 0.400624
# [1234]	valid_0's binary_logloss: 0.400634
# [1235]	valid_0's binary_logloss: 0.400641
# [1236]	valid_0's binary_logloss: 0.400638
# [1237]	valid_0's binary_logloss: 0.400644
# [1238]	valid_0's binary_logloss: 0.400646
# [1239]	valid_0's binary_logloss: 0.400643
# [1240]	valid_0's binary_logloss: 0.400634
# [1241]	valid_0's binary_logloss: 0.400632
# [1242]	valid_0's binary_logloss: 0.400638
# [1243]	valid_0's binary_logloss: 0.400629
# [1244]	valid_0's binary_logloss: 0.400633
# [1245]	valid_0's binary_logloss: 0.400643
# [1246]	valid_0's binary_logloss: 0.400645
# [1247]	valid_0's binary_logloss: 0.400649
# [1248]	valid_0's binary_logloss: 0.400653
# [1249]	valid_0's binary_logloss: 0.400649
# [1250]	valid_0's binary_logloss: 0.400651
# [1251]	valid_0's binary_logloss: 0.40065
# [1252]	valid_0's binary_logloss: 0.400659
# [1253]	valid_0's binary_logloss: 0.400666
# [1254]	valid_0's binary_logloss: 0.40066
# [1255]	valid_0's binary_logloss: 0.400661
# [1256]	valid_0's binary_logloss: 0.400657
# [1257]	valid_0's binary_logloss: 0.400659
# [1258]	valid_0's binary_logloss: 0.400664
# [1259]	valid_0's binary_logloss: 0.400667
# [1260]	valid_0's binary_logloss: 0.400668
# [1261]	valid_0's binary_logloss: 0.400664
# [1262]	valid_0's binary_logloss: 0.40067
# [1263]	valid_0's binary_logloss: 0.400673
# [1264]	valid_0's binary_logloss: 0.400682
# [1265]	valid_0's binary_logloss: 0.400685
# [1266]	valid_0's binary_logloss: 0.400687
# [1267]	valid_0's binary_logloss: 0.400683
# [1268]	valid_0's binary_logloss: 0.400673
# [1269]	valid_0's binary_logloss: 0.400663
# [1270]	valid_0's binary_logloss: 0.400664
# [1271]	valid_0's binary_logloss: 0.400659
# [1272]	valid_0's binary_logloss: 0.400662
# [1273]	valid_0's binary_logloss: 0.400659
# [1274]	valid_0's binary_logloss: 0.40065
# [1275]	valid_0's binary_logloss: 0.400654
# [1276]	valid_0's binary_logloss: 0.400653
# [1277]	valid_0's binary_logloss: 0.400647
# [1278]	valid_0's binary_logloss: 0.40065
# [1279]	valid_0's binary_logloss: 0.400651
# [1280]	valid_0's binary_logloss: 0.400649
# [1281]	valid_0's binary_logloss: 0.400649
# [1282]	valid_0's binary_logloss: 0.400643
# [1283]	valid_0's binary_logloss: 0.400644
# [1284]	valid_0's binary_logloss: 0.400636
# [1285]	valid_0's binary_logloss: 0.400644
# [1286]	valid_0's binary_logloss: 0.400651
# [1287]	valid_0's binary_logloss: 0.400656
# [1288]	valid_0's binary_logloss: 0.400657
# [1289]	valid_0's binary_logloss: 0.400651
# [1290]	valid_0's binary_logloss: 0.400659
# [1291]	valid_0's binary_logloss: 0.400646
# [1292]	valid_0's binary_logloss: 0.400639
# [1293]	valid_0's binary_logloss: 0.400636
# [1294]	valid_0's binary_logloss: 0.400629
# [1295]	valid_0's binary_logloss: 0.400632
# [1296]	valid_0's binary_logloss: 0.40063
# [1297]	valid_0's binary_logloss: 0.400625
# [1298]	valid_0's binary_logloss: 0.400621
# [1299]	valid_0's binary_logloss: 0.400615
# [1300]	valid_0's binary_logloss: 0.400614
# [1301]	valid_0's binary_logloss: 0.400612
# [1302]	valid_0's binary_logloss: 0.400611
# [1303]	valid_0's binary_logloss: 0.40061
# [1304]	valid_0's binary_logloss: 0.400614
# [1305]	valid_0's binary_logloss: 0.400614
# [1306]	valid_0's binary_logloss: 0.400623
# [1307]	valid_0's binary_logloss: 0.400625
# [1308]	valid_0's binary_logloss: 0.400635
# [1309]	valid_0's binary_logloss: 0.400643
# [1310]	valid_0's binary_logloss: 0.400648
# [1311]	valid_0's binary_logloss: 0.400652
# [1312]	valid_0's binary_logloss: 0.400654
# [1313]	valid_0's binary_logloss: 0.400656
# [1314]	valid_0's binary_logloss: 0.400654
# [1315]	valid_0's binary_logloss: 0.40066
# [1316]	valid_0's binary_logloss: 0.400662
# [1317]	valid_0's binary_logloss: 0.400657
# [1318]	valid_0's binary_logloss: 0.400643
# [1319]	valid_0's binary_logloss: 0.400644
# [1320]	valid_0's binary_logloss: 0.400651
# [1321]	valid_0's binary_logloss: 0.400656
# [1322]	valid_0's binary_logloss: 0.400658
# [1323]	valid_0's binary_logloss: 0.40066
# [1324]	valid_0's binary_logloss: 0.400667
# [1325]	valid_0's binary_logloss: 0.400669
# [1326]	valid_0's binary_logloss: 0.400668
# [1327]	valid_0's binary_logloss: 0.400658
# [1328]	valid_0's binary_logloss: 0.400656
# [1329]	valid_0's binary_logloss: 0.400641
# [1330]	valid_0's binary_logloss: 0.400647
# [1331]	valid_0's binary_logloss: 0.400645
# [1332]	valid_0's binary_logloss: 0.400648
# [1333]	valid_0's binary_logloss: 0.400649
# [1334]	valid_0's binary_logloss: 0.40065
# [1335]	valid_0's binary_logloss: 0.400657
# [1336]	valid_0's binary_logloss: 0.400667
# [1337]	valid_0's binary_logloss: 0.400669
# [1338]	valid_0's binary_logloss: 0.400669
# [1339]	valid_0's binary_logloss: 0.400676
# [1340]	valid_0's binary_logloss: 0.400679
# [1341]	valid_0's binary_logloss: 0.400683
# [1342]	valid_0's binary_logloss: 0.400679
# [1343]	valid_0's binary_logloss: 0.400684
# [1344]	valid_0's binary_logloss: 0.400687
# [1345]	valid_0's binary_logloss: 0.400686
# [1346]	valid_0's binary_logloss: 0.400699
# [1347]	valid_0's binary_logloss: 0.400701
# [1348]	valid_0's binary_logloss: 0.4007
# [1349]	valid_0's binary_logloss: 0.400697
# [1350]	valid_0's binary_logloss: 0.400688
# [1351]	valid_0's binary_logloss: 0.40069
# [1352]	valid_0's binary_logloss: 0.40069
# [1353]	valid_0's binary_logloss: 0.400687
# [1354]	valid_0's binary_logloss: 0.400695
# [1355]	valid_0's binary_logloss: 0.400694
# [1356]	valid_0's binary_logloss: 0.400702
# [1357]	valid_0's binary_logloss: 0.400706
# [1358]	valid_0's binary_logloss: 0.4007
# [1359]	valid_0's binary_logloss: 0.400714
# [1360]	valid_0's binary_logloss: 0.400707
# [1361]	valid_0's binary_logloss: 0.400703
# [1362]	valid_0's binary_logloss: 0.400699
# [1363]	valid_0's binary_logloss: 0.400699
# [1364]	valid_0's binary_logloss: 0.400697
# [1365]	valid_0's binary_logloss: 0.400698
# [1366]	valid_0's binary_logloss: 0.400696
# [1367]	valid_0's binary_logloss: 0.400692
# [1368]	valid_0's binary_logloss: 0.400691
# [1369]	valid_0's binary_logloss: 0.400688
# [1370]	valid_0's binary_logloss: 0.400688
# [1371]	valid_0's binary_logloss: 0.400687
# [1372]	valid_0's binary_logloss: 0.400678
# [1373]	valid_0's binary_logloss: 0.400675
# [1374]	valid_0's binary_logloss: 0.40068
# [1375]	valid_0's binary_logloss: 0.400681
# [1376]	valid_0's binary_logloss: 0.400675
# [1377]	valid_0's binary_logloss: 0.400674
# [1378]	valid_0's binary_logloss: 0.40067
# [1379]	valid_0's binary_logloss: 0.40068
# [1380]	valid_0's binary_logloss: 0.400684
# [1381]	valid_0's binary_logloss: 0.400694
# [1382]	valid_0's binary_logloss: 0.400691
# [1383]	valid_0's binary_logloss: 0.400688
# Early stopping, best iteration is:
# [883]	valid_0's binary_logloss: 0.400266

# %%
print(gbm.best_score)
print(gbm.best_iteration)
# Out:
# defaultdict(<class 'collections.OrderedDict'>, {'valid_0': OrderedDict([('binary_logloss', 0.4002658118299879)])})
# 883

# %%
from operator import itemgetter
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import roc_auc_score

def run_default_test(train, test, features, target, random_state=0):
    eta = 0.1
    max_depth = 5
    subsample = 0.8
    colsample_bytree = 0.8
    print('XGBoost params. ETA: {}, MAX_DEPTH: {}, SUBSAMPLE: {}, COLSAMPLE_BY_TREE: {}'.format(eta, max_depth, subsample, colsample_bytree))
    params = {
        "objective": "binary:logistic",
        "booster" : "gbtree",
        "eval_metric": "logloss",
        "eta": eta,
        "max_depth": max_depth,
        "subsample": subsample,
        "colsample_bytree": colsample_bytree,
        "silent": 1,
        "seed": random_state
    }
    num_boost_round = 260
    early_stopping_rounds = 20
    test_size = 0.2

    X_train, X_valid = train_test_split(train, test_size=test_size, random_state=random_state)
    y_train = X_train[target]
    y_valid = X_valid[target]
    dtrain = xgb.DMatrix(X_train[features], y_train)
    dvalid = xgb.DMatrix(X_valid[features], y_valid)
    watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
    gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=True)

# %%
features = ['C1', 'banner_pos', 'device_type', 'device_conn_type', 'C14',
       'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'hour_of_day',
       'site_id_int', 'site_domain_int', 'site_category_int', 'app_id_int',
       'app_domain_int', 'app_category_int', 'device_id_int', 'device_ip_int',
       'device_model_int', 'day_of_week_int']
run_default_test(train, y_target, features, 'click')
# Out:
# XGBoost params. ETA: 0.1, MAX_DEPTH: 5, SUBSAMPLE: 0.8, COLSAMPLE_BY_TREE: 0.8
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [0]	train-logloss:0.648454	eval-logloss:0.648461
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 20 rounds.
# [1]	train-logloss:0.611867	eval-logloss:0.611911
# [2]	train-logloss:0.581667	eval-logloss:0.581723
# [3]	train-logloss:0.556635	eval-logloss:0.5567
# [4]	train-logloss:0.535813	eval-logloss:0.535881
# [5]	train-logloss:0.518201	eval-logloss:0.518266
# [6]	train-logloss:0.503194	eval-logloss:0.503262
# [7]	train-logloss:0.490581	eval-logloss:0.490692
# [8]	train-logloss:0.479855	eval-logloss:0.479982
# [9]	train-logloss:0.470718	eval-logloss:0.470865
# [10]	train-logloss:0.462977	eval-logloss:0.463141
# [11]	train-logloss:0.456365	eval-logloss:0.456529
# [12]	train-logloss:0.450928	eval-logloss:0.45111
# [13]	train-logloss:0.446219	eval-logloss:0.446436
# [14]	train-logloss:0.442187	eval-logloss:0.442428
# [15]	train-logloss:0.438723	eval-logloss:0.438976
# [16]	train-logloss:0.435564	eval-logloss:0.435817
# [17]	train-logloss:0.433112	eval-logloss:0.433362
# [18]	train-logloss:0.430914	eval-logloss:0.431187
# [19]	train-logloss:0.429051	eval-logloss:0.429328
# [20]	train-logloss:0.427303	eval-logloss:0.42759
# [21]	train-logloss:0.425818	eval-logloss:0.426118
# [22]	train-logloss:0.424566	eval-logloss:0.424883
# [23]	train-logloss:0.423494	eval-logloss:0.423842
# [24]	train-logloss:0.422531	eval-logloss:0.422902
# [25]	train-logloss:0.421637	eval-logloss:0.421987
# [26]	train-logloss:0.420764	eval-logloss:0.421116
# [27]	train-logloss:0.420142	eval-logloss:0.420505
# [28]	train-logloss:0.419606	eval-logloss:0.419979
# [29]	train-logloss:0.419053	eval-logloss:0.419447
# [30]	train-logloss:0.41851	eval-logloss:0.418903
# [31]	train-logloss:0.41798	eval-logloss:0.418377
# [32]	train-logloss:0.417679	eval-logloss:0.418083
# [33]	train-logloss:0.417367	eval-logloss:0.41777
# [34]	train-logloss:0.417168	eval-logloss:0.417577
# [35]	train-logloss:0.416839	eval-logloss:0.417243
# [36]	train-logloss:0.41648	eval-logloss:0.416886
# [37]	train-logloss:0.416197	eval-logloss:0.416613
# [38]	train-logloss:0.415981	eval-logloss:0.416419
# [39]	train-logloss:0.415839	eval-logloss:0.416277
# [40]	train-logloss:0.415625	eval-logloss:0.416075
# [41]	train-logloss:0.415314	eval-logloss:0.415793
# [42]	train-logloss:0.414984	eval-logloss:0.415493
# [43]	train-logloss:0.414845	eval-logloss:0.415355
# [44]	train-logloss:0.414601	eval-logloss:0.415123
# [45]	train-logloss:0.414527	eval-logloss:0.415053
# [46]	train-logloss:0.414413	eval-logloss:0.414945
# [47]	train-logloss:0.414046	eval-logloss:0.414588
# [48]	train-logloss:0.413896	eval-logloss:0.41443
# [49]	train-logloss:0.413679	eval-logloss:0.414238
# [50]	train-logloss:0.413606	eval-logloss:0.414163
# [51]	train-logloss:0.413523	eval-logloss:0.41409
# [52]	train-logloss:0.413238	eval-logloss:0.413797
# [53]	train-logloss:0.413008	eval-logloss:0.413601
# [54]	train-logloss:0.412909	eval-logloss:0.413492
# [55]	train-logloss:0.412766	eval-logloss:0.413355
# [56]	train-logloss:0.412561	eval-logloss:0.413167
# [57]	train-logloss:0.412274	eval-logloss:0.412879
# [58]	train-logloss:0.412182	eval-logloss:0.412816
# [59]	train-logloss:0.411976	eval-logloss:0.412619
# [60]	train-logloss:0.411929	eval-logloss:0.41258
# [61]	train-logloss:0.411823	eval-logloss:0.41247
# [62]	train-logloss:0.411675	eval-logloss:0.412329
# [63]	train-logloss:0.411621	eval-logloss:0.412286
# [64]	train-logloss:0.411582	eval-logloss:0.412256
# [65]	train-logloss:0.41146	eval-logloss:0.412138
# [66]	train-logloss:0.411403	eval-logloss:0.412082
# [67]	train-logloss:0.411366	eval-logloss:0.412051
# [68]	train-logloss:0.411182	eval-logloss:0.411874
# [69]	train-logloss:0.411134	eval-logloss:0.411828
# [70]	train-logloss:0.411081	eval-logloss:0.41177
# [71]	train-logloss:0.410991	eval-logloss:0.411679
# [72]	train-logloss:0.410918	eval-logloss:0.411605
# [73]	train-logloss:0.410712	eval-logloss:0.411413
# [74]	train-logloss:0.410644	eval-logloss:0.411342
# [75]	train-logloss:0.410559	eval-logloss:0.411266
# [76]	train-logloss:0.410403	eval-logloss:0.411125
# [77]	train-logloss:0.410343	eval-logloss:0.411078
# [78]	train-logloss:0.41013	eval-logloss:0.410889
# [79]	train-logloss:0.410079	eval-logloss:0.410831
# [80]	train-logloss:0.40995	eval-logloss:0.4107
# [81]	train-logloss:0.409926	eval-logloss:0.410695
# [82]	train-logloss:0.409723	eval-logloss:0.410509
# [83]	train-logloss:0.409671	eval-logloss:0.410461
# [84]	train-logloss:0.409565	eval-logloss:0.410379
# [85]	train-logloss:0.409442	eval-logloss:0.410266
# [86]	train-logloss:0.409368	eval-logloss:0.410201
# [87]	train-logloss:0.409225	eval-logloss:0.410077
# [88]	train-logloss:0.409144	eval-logloss:0.410001
# [89]	train-logloss:0.409108	eval-logloss:0.409977
# [90]	train-logloss:0.408923	eval-logloss:0.409807
# [91]	train-logloss:0.408861	eval-logloss:0.409756
# [92]	train-logloss:0.408798	eval-logloss:0.409714
# [93]	train-logloss:0.408703	eval-logloss:0.409629
# [94]	train-logloss:0.408557	eval-logloss:0.409483
# [95]	train-logloss:0.408418	eval-logloss:0.40935
# [96]	train-logloss:0.408323	eval-logloss:0.409282
# [97]	train-logloss:0.408298	eval-logloss:0.409263
# [98]	train-logloss:0.408213	eval-logloss:0.409186
# [99]	train-logloss:0.407927	eval-logloss:0.408917
# [100]	train-logloss:0.40782	eval-logloss:0.408827
# [101]	train-logloss:0.407788	eval-logloss:0.408804
# [102]	train-logloss:0.40773	eval-logloss:0.408753
# [103]	train-logloss:0.407645	eval-logloss:0.408661
# [104]	train-logloss:0.407562	eval-logloss:0.408586
# [105]	train-logloss:0.407462	eval-logloss:0.408506
# [106]	train-logloss:0.40742	eval-logloss:0.408473
# [107]	train-logloss:0.407326	eval-logloss:0.408406
# [108]	train-logloss:0.40725	eval-logloss:0.408357
# [109]	train-logloss:0.407157	eval-logloss:0.408276
# [110]	train-logloss:0.407081	eval-logloss:0.408204
# [111]	train-logloss:0.406928	eval-logloss:0.408063
# [112]	train-logloss:0.406909	eval-logloss:0.408052
# [113]	train-logloss:0.40673	eval-logloss:0.407881
# [114]	train-logloss:0.406707	eval-logloss:0.407857
# [115]	train-logloss:0.406681	eval-logloss:0.407841
# [116]	train-logloss:0.406523	eval-logloss:0.407708
# [117]	train-logloss:0.406456	eval-logloss:0.407658
# [118]	train-logloss:0.406371	eval-logloss:0.407572
# [119]	train-logloss:0.4063	eval-logloss:0.407509
# [120]	train-logloss:0.406238	eval-logloss:0.407465
# [121]	train-logloss:0.406178	eval-logloss:0.407428
# [122]	train-logloss:0.406119	eval-logloss:0.407386
# [123]	train-logloss:0.406092	eval-logloss:0.407363
# [124]	train-logloss:0.406076	eval-logloss:0.407361
# [125]	train-logloss:0.405962	eval-logloss:0.407245
# [126]	train-logloss:0.40588	eval-logloss:0.407175
# [127]	train-logloss:0.405811	eval-logloss:0.407112
# [128]	train-logloss:0.405714	eval-logloss:0.407032
# [129]	train-logloss:0.405683	eval-logloss:0.407011
# [130]	train-logloss:0.405629	eval-logloss:0.406972
# [131]	train-logloss:0.405597	eval-logloss:0.406945
# [132]	train-logloss:0.405585	eval-logloss:0.406938
# [133]	train-logloss:0.405541	eval-logloss:0.406903
# [134]	train-logloss:0.405448	eval-logloss:0.406824
# [135]	train-logloss:0.405433	eval-logloss:0.406812
# [136]	train-logloss:0.405403	eval-logloss:0.406784
# [137]	train-logloss:0.40534	eval-logloss:0.406727
# [138]	train-logloss:0.405316	eval-logloss:0.406713
# [139]	train-logloss:0.405172	eval-logloss:0.406575
# [140]	train-logloss:0.405123	eval-logloss:0.406543
# [141]	train-logloss:0.40503	eval-logloss:0.406464
# [142]	train-logloss:0.404995	eval-logloss:0.406447
# [143]	train-logloss:0.404965	eval-logloss:0.406425
# [144]	train-logloss:0.404888	eval-logloss:0.406348
# [145]	train-logloss:0.404835	eval-logloss:0.406302
# [146]	train-logloss:0.404794	eval-logloss:0.40627
# [147]	train-logloss:0.404695	eval-logloss:0.406193
# [148]	train-logloss:0.404662	eval-logloss:0.406177
# [149]	train-logloss:0.404554	eval-logloss:0.406085
# [150]	train-logloss:0.404521	eval-logloss:0.406064
# [151]	train-logloss:0.404464	eval-logloss:0.406032
# [152]	train-logloss:0.404412	eval-logloss:0.405983
# [153]	train-logloss:0.404342	eval-logloss:0.405921
# [154]	train-logloss:0.404326	eval-logloss:0.405915
# [155]	train-logloss:0.404244	eval-logloss:0.405849
# [156]	train-logloss:0.404221	eval-logloss:0.405836
# [157]	train-logloss:0.404157	eval-logloss:0.405783
# [158]	train-logloss:0.404057	eval-logloss:0.405711
# [159]	train-logloss:0.403975	eval-logloss:0.405642
# [160]	train-logloss:0.403941	eval-logloss:0.40561
# [161]	train-logloss:0.403857	eval-logloss:0.405539
# [162]	train-logloss:0.403839	eval-logloss:0.40553
# [163]	train-logloss:0.403818	eval-logloss:0.405516
# [164]	train-logloss:0.403803	eval-logloss:0.40551
# [165]	train-logloss:0.403759	eval-logloss:0.40548
# [166]	train-logloss:0.403717	eval-logloss:0.405453
# [167]	train-logloss:0.403652	eval-logloss:0.405391
# [168]	train-logloss:0.403631	eval-logloss:0.405383
# [169]	train-logloss:0.403543	eval-logloss:0.405312
# [170]	train-logloss:0.403514	eval-logloss:0.405295
# [171]	train-logloss:0.403423	eval-logloss:0.405216
# [172]	train-logloss:0.403296	eval-logloss:0.405086
# [173]	train-logloss:0.403224	eval-logloss:0.405026
# [174]	train-logloss:0.403165	eval-logloss:0.404991
# [175]	train-logloss:0.403108	eval-logloss:0.40495
# [176]	train-logloss:0.403072	eval-logloss:0.404928
# [177]	train-logloss:0.40301	eval-logloss:0.404878
# [178]	train-logloss:0.402913	eval-logloss:0.404809
# [179]	train-logloss:0.402854	eval-logloss:0.404755
# [180]	train-logloss:0.402822	eval-logloss:0.404737
# [181]	train-logloss:0.402691	eval-logloss:0.404615
# [182]	train-logloss:0.402673	eval-logloss:0.404606
# [183]	train-logloss:0.402651	eval-logloss:0.404596
# [184]	train-logloss:0.402587	eval-logloss:0.404543
# [185]	train-logloss:0.402528	eval-logloss:0.40449
# [186]	train-logloss:0.402467	eval-logloss:0.404442
# [187]	train-logloss:0.402446	eval-logloss:0.404431
# [188]	train-logloss:0.402408	eval-logloss:0.404417
# [189]	train-logloss:0.402385	eval-logloss:0.404398
# [190]	train-logloss:0.402345	eval-logloss:0.404367
# [191]	train-logloss:0.402301	eval-logloss:0.404332
# [192]	train-logloss:0.402265	eval-logloss:0.404301
# [193]	train-logloss:0.402235	eval-logloss:0.404288
# [194]	train-logloss:0.402214	eval-logloss:0.404286
# [195]	train-logloss:0.402147	eval-logloss:0.404227
# [196]	train-logloss:0.402132	eval-logloss:0.40422
# [197]	train-logloss:0.402053	eval-logloss:0.404154
# [198]	train-logloss:0.401974	eval-logloss:0.404092
# [199]	train-logloss:0.401919	eval-logloss:0.404047
# [200]	train-logloss:0.401833	eval-logloss:0.403961
# [201]	train-logloss:0.401783	eval-logloss:0.403918
# [202]	train-logloss:0.401744	eval-logloss:0.403885
# [203]	train-logloss:0.401685	eval-logloss:0.403838
# [204]	train-logloss:0.401636	eval-logloss:0.403811
# [205]	train-logloss:0.401565	eval-logloss:0.403754
# [206]	train-logloss:0.401533	eval-logloss:0.403735
# [207]	train-logloss:0.401507	eval-logloss:0.403718
# [208]	train-logloss:0.401491	eval-logloss:0.403722
# [209]	train-logloss:0.401481	eval-logloss:0.40372
# [210]	train-logloss:0.401444	eval-logloss:0.403691
# [211]	train-logloss:0.401375	eval-logloss:0.403629
# [212]	train-logloss:0.401356	eval-logloss:0.403619
# [213]	train-logloss:0.401338	eval-logloss:0.403615
# [214]	train-logloss:0.401296	eval-logloss:0.403589
# [215]	train-logloss:0.401266	eval-logloss:0.403572
# [216]	train-logloss:0.401246	eval-logloss:0.403563
# [217]	train-logloss:0.401203	eval-logloss:0.403537
# [218]	train-logloss:0.401163	eval-logloss:0.403517
# [219]	train-logloss:0.401144	eval-logloss:0.403517
# [220]	train-logloss:0.401103	eval-logloss:0.403496
# [221]	train-logloss:0.401069	eval-logloss:0.40348
# [222]	train-logloss:0.401026	eval-logloss:0.403456
# [223]	train-logloss:0.400992	eval-logloss:0.40344
# [224]	train-logloss:0.400966	eval-logloss:0.40342
# [225]	train-logloss:0.400935	eval-logloss:0.403398
# [226]	train-logloss:0.400916	eval-logloss:0.403389
# [227]	train-logloss:0.400866	eval-logloss:0.403355
# [228]	train-logloss:0.400786	eval-logloss:0.403274
# [229]	train-logloss:0.400769	eval-logloss:0.403263
# [230]	train-logloss:0.40075	eval-logloss:0.403252
# [231]	train-logloss:0.400726	eval-logloss:0.403245
# [232]	train-logloss:0.400683	eval-logloss:0.403215
# [233]	train-logloss:0.400645	eval-logloss:0.403189
# [234]	train-logloss:0.400618	eval-logloss:0.403168
# [235]	train-logloss:0.400586	eval-logloss:0.403146
# [236]	train-logloss:0.400538	eval-logloss:0.403112
# [237]	train-logloss:0.400504	eval-logloss:0.403089
# [238]	train-logloss:0.400468	eval-logloss:0.403066
# [239]	train-logloss:0.400456	eval-logloss:0.403063
# [240]	train-logloss:0.400414	eval-logloss:0.403046
# [241]	train-logloss:0.400369	eval-logloss:0.40301
# [242]	train-logloss:0.400321	eval-logloss:0.402976
# [243]	train-logloss:0.400292	eval-logloss:0.402952
# [244]	train-logloss:0.400253	eval-logloss:0.402924
# [245]	train-logloss:0.400225	eval-logloss:0.402899
# [246]	train-logloss:0.4002	eval-logloss:0.402881
# [247]	train-logloss:0.400179	eval-logloss:0.402881
# [248]	train-logloss:0.400115	eval-logloss:0.402825
# [249]	train-logloss:0.40008	eval-logloss:0.402797
# [250]	train-logloss:0.400046	eval-logloss:0.402781
# [251]	train-logloss:0.400033	eval-logloss:0.402781
# [252]	train-logloss:0.399975	eval-logloss:0.402735
# [253]	train-logloss:0.399957	eval-logloss:0.402725
# [254]	train-logloss:0.399951	eval-logloss:0.402722
# [255]	train-logloss:0.399892	eval-logloss:0.402685
# [256]	train-logloss:0.399869	eval-logloss:0.402679
# [257]	train-logloss:0.399849	eval-logloss:0.402672
# [258]	train-logloss:0.399823	eval-logloss:0.402653
# [259]	train-logloss:0.399781	eval-logloss:0.402627
